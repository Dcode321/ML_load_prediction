# %% [markdown]
# # Importing Libraries

# %% [markdown]
# Importing standard libraries necessary to organize and split data for neural network training. To use the LSTM Recurrent neural network, we use the tensorflow library keras. The model uses "Adam" as the optimizer and the activation function used is "Relu"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.metrics import MAPE
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error as mse

# %%
ld = pd.read_csv("Load_data.csv")
ld.head()
# Out:
#    Load
# 0  1001
# 1   967
# 2   946
# 3   939
# 4   934

# %%
ld.plot()
ld.size
# Out:
# 17544

# %%
da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
r = np.array(da, dtype='datetime64[h]')
rr = pd.DataFrame(r, columns=['Time'])
rr.tail()
# Out:
# C:\Users\prede\AppData\Local\Temp\ipykernel_1772\1644015983.py:1: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
#                      Time
# 17539 2005-10-31 20:00:00
# 17540 2005-10-31 21:00:00
# 17541 2005-10-31 22:00:00
# 17542 2005-10-31 23:00:00
# 17543 2005-11-01 00:00:00

# %%
ldd = pd.concat([rr, ld], axis=1)
ldd.Time = pd.to_datetime(ldd.Time)
print(ldd.info())
ldd.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    17544 non-null  datetime64[ns]
#  1   Load    17544 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 274.2 KB
# None
#                  Time  Load
# 0 2003-11-01 01:00:00  1001
# 1 2003-11-01 02:00:00   967
# 2 2003-11-01 03:00:00   946
# 3 2003-11-01 04:00:00   939
# 4 2003-11-01 05:00:00   934

# %%
temp = pd.read_csv("temp.csv")
ldt = pd.concat([ldd, temp], axis=1)
ldt=ldt.set_index("Time")
ldt.head()
#The dataframe including the temperature data
# Out:
#                      Load  Temp (C)
# Time
# 2003-11-01 01:00:00  1001      16.8
# 2003-11-01 02:00:00   967      15.9
# 2003-11-01 03:00:00   946      15.9
# 2003-11-01 04:00:00   939      16.9
# 2003-11-01 05:00:00   934      16.3

# %%
# ldt.plot(y='Load', xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,8,23,0,0)])

# %%
#Generating the time in "Seconds" to generate a cos and sin map for periodicity relevance
ldt['Sec'] = ldt.index.map(pd.Timestamp.timestamp)
ldt
# Out:
#                      Load  Temp (C)           Sec
# Time
# 2003-11-01 01:00:00  1001      16.8  1.067648e+09
# 2003-11-01 02:00:00   967      15.9  1.067652e+09
# 2003-11-01 03:00:00   946      15.9  1.067656e+09
# 2003-11-01 04:00:00   939      16.9  1.067659e+09
# 2003-11-01 05:00:00   934      16.3  1.067663e+09
# ...                   ...       ...           ...
# 2005-10-31 20:00:00  1352      11.7  1.130789e+09
# 2005-10-31 21:00:00  1348      11.3  1.130792e+09
# 2005-10-31 22:00:00  1266      11.4  1.130796e+09
# 2005-10-31 23:00:00  1173      11.4  1.130800e+09
# 2005-11-01 00:00:00  1077      11.4  1.130803e+09
#
# [17544 rows x 3 columns]

# %%
day = 86400 
#86400 is the number of seconds in a day
year = 31556952 
#31556952 is the number of seconds in an year

ldt['DSin'] = np.sin(ldt['Sec'] * (2*np.pi /day))
ldt['DCos'] = np.cos(ldt['Sec'] * (2*np.pi /day))
ldt['YSin'] = np.sin(ldt['Sec'] * (2*np.pi /year))
ldt['YCos'] = np.cos(ldt['Sec'] * (2*np.pi /year))
ldt.head()
# Out:
#                      Load  Temp (C)           Sec      DSin      DCos  \
# Time
# 2003-11-01 01:00:00  1001      16.8  1.067648e+09  0.258819  0.965926
# 2003-11-01 02:00:00   967      15.9  1.067652e+09  0.500000  0.866025
# 2003-11-01 03:00:00   946      15.9  1.067656e+09  0.707107  0.707107
# 2003-11-01 04:00:00   939      16.9  1.067659e+09  0.866025  0.500000
# 2003-11-01 05:00:00   934      16.3  1.067663e+09  0.965926  0.258819
#
#                          YSin      YCos
# Time
# 2003-11-01 01:00:00 -0.868846  0.495082
# 2003-11-01 02:00:00 -0.868491  0.495704
# 2003-11-01 03:00:00 -0.868136  0.496327
# 2003-11-01 04:00:00 -0.867780  0.496949
# 2003-11-01 05:00:00 -0.867423  0.497571

# %%
ldt =ldt.drop('Sec', axis=1)
ldt.head()
#Dropping the "Seconds" column
# Out:
#                      Load  Temp (C)      DSin      DCos      YSin      YCos
# Time
# 2003-11-01 01:00:00  1001      16.8  0.258819  0.965926 -0.868846  0.495082
# 2003-11-01 02:00:00   967      15.9  0.500000  0.866025 -0.868491  0.495704
# 2003-11-01 03:00:00   946      15.9  0.707107  0.707107 -0.868136  0.496327
# 2003-11-01 04:00:00   939      16.9  0.866025  0.500000 -0.867780  0.496949
# 2003-11-01 05:00:00   934      16.3  0.965926  0.258819 -0.867423  0.497571

# %% [markdown]
# The Day sin and cos values with the Year sin and cos values shows the model that there exists a periodicity with a period of 24 hrs and as well as an whole year since the whole year is periodic in nature with offsets based on variable usage

# %% [markdown]
# ## Splitting the dataset based on seasons

# %%
win = pd.concat([ldt['2003-12-01':'2004-02-29'],ldt['2004-12-01':'2005-02-28']])
frames = [ldt['2003-11-01':'2003-11-30'],ldt['2004-09-01':'2004-11-30'],ldt['2005-09-01':'2005-10-30']]
fal = pd.concat(frames)
spr = pd.concat([ldt['2004-03-01':'2004-05-31'],ldt['2005-03-01':'2005-05-31']])
sue = pd.concat([ldt['2004-06-01':'2004-08-31'],ldt['2005-06-01':'2005-08-31']])


win.to_csv('win.csv',index=False)
fal.to_csv('fal.csv',index=False)
spr.to_csv('spr.csv',index=False)
sue.to_csv('sum.csv',index=False)

# %%
len(sue['2004-06-01':'2004-08-31'])
# Out:
# 2208

# %% [markdown]
# ## Sliding Window

# %%
#We generate the sliding window which is required for the LSTM model. The window size can be arbitrary and can depend on the dataset. Here, we use 5 hours of previous data to predict the next hour, Hence the size of the window will be 5. This can also be changed later for further tweaks to increase the accuracy of the model.
def dataframe_win(df, w_size=7):
    df_np = df.to_numpy()
    X=[]
    y=[]
    for i in range(len(df_np)-w_size):
        row =[r for r in df_np[i:i+w_size]]
        X.append(row)
        label = df_np[i+w_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %% [markdown]
# # Winter season dataset training and prediction

# %%
X, y = dataframe_win(win)
X.shape, y.shape
# Out:
# ((4337, 7, 6), (4337,))

# %%
X_train, y_train = X[:2184], y[:2184]
X_val, y_val = X[2184:3672], y[2184:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2184, 7, 6), (2184,), (1488, 7, 6), (1488,), (665, 7, 6), (665,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model1 = Sequential()
model1.add(InputLayer((7, 6)))
model1.add(Conv1D(64, kernel_size=2))
model1.add(Flatten())         
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 6, 64)             832
#
#  flatten (Flatten)           (None, 384)               0
#
#  dense (Dense)               (None, 8)                 3080
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 3,921
# Trainable params: 3,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelWIN_CNN/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0487 - root_mean_squared_error: 0.2206
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 2s 16ms/step - loss: 0.0482 - root_mean_squared_error: 0.2196 - val_loss: 0.0879 - val_root_mean_squared_error: 0.2965
# Epoch 2/20
# 56/69 [=======================>......] - ETA: 0s - loss: 0.0445 - root_mean_squared_error: 0.2109
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0436 - root_mean_squared_error: 0.2088 - val_loss: 0.0837 - val_root_mean_squared_error: 0.2892
# Epoch 3/20
# 52/69 [=====================>........] - ETA: 0s - loss: 0.0412 - root_mean_squared_error: 0.2030
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0399 - root_mean_squared_error: 0.1998 - val_loss: 0.0796 - val_root_mean_squared_error: 0.2821
# Epoch 4/20
# 54/69 [======================>.......] - ETA: 0s - loss: 0.0386 - root_mean_squared_error: 0.1964
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0375 - root_mean_squared_error: 0.1937 - val_loss: 0.0790 - val_root_mean_squared_error: 0.2811
# Epoch 5/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0353 - root_mean_squared_error: 0.1879
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0355 - root_mean_squared_error: 0.1885 - val_loss: 0.0759 - val_root_mean_squared_error: 0.2755
# Epoch 6/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0336 - root_mean_squared_error: 0.1834
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0339 - root_mean_squared_error: 0.1842 - val_loss: 0.0744 - val_root_mean_squared_error: 0.2728
# Epoch 7/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0324 - root_mean_squared_error: 0.1799 - val_loss: 0.0746 - val_root_mean_squared_error: 0.2731
# Epoch 8/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0313 - root_mean_squared_error: 0.1768
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0315 - root_mean_squared_error: 0.1776 - val_loss: 0.0713 - val_root_mean_squared_error: 0.2671
# Epoch 9/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0299 - root_mean_squared_error: 0.1730
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0302 - root_mean_squared_error: 0.1739 - val_loss: 0.0709 - val_root_mean_squared_error: 0.2664
# Epoch 10/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0294 - root_mean_squared_error: 0.1715
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0294 - root_mean_squared_error: 0.1715 - val_loss: 0.0689 - val_root_mean_squared_error: 0.2625
# Epoch 11/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0290 - root_mean_squared_error: 0.1703
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0289 - root_mean_squared_error: 0.1700 - val_loss: 0.0688 - val_root_mean_squared_error: 0.2623
# Epoch 12/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0278 - root_mean_squared_error: 0.1667 - val_loss: 0.0696 - val_root_mean_squared_error: 0.2639
# Epoch 13/20
# 55/69 [======================>.......] - ETA: 0s - loss: 0.0262 - root_mean_squared_error: 0.1620
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0271 - root_mean_squared_error: 0.1646 - val_loss: 0.0687 - val_root_mean_squared_error: 0.2621
# Epoch 14/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0262 - root_mean_squared_error: 0.1617
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0265 - root_mean_squared_error: 0.1629 - val_loss: 0.0683 - val_root_mean_squared_error: 0.2614
# Epoch 15/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0260 - root_mean_squared_error: 0.1611 - val_loss: 0.0688 - val_root_mean_squared_error: 0.2624
# Epoch 16/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0706 - val_root_mean_squared_error: 0.2658
# Epoch 17/20
# 58/69 [========================>.....] - ETA: 0s - loss: 0.0253 - root_mean_squared_error: 0.1590
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0256 - root_mean_squared_error: 0.1600 - val_loss: 0.0662 - val_root_mean_squared_error: 0.2573
# Epoch 18/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0251 - root_mean_squared_error: 0.1584
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# INFO:tensorflow:Assets written to: modelWIN_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0247 - root_mean_squared_error: 0.1571 - val_loss: 0.0656 - val_root_mean_squared_error: 0.2562
# Epoch 19/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0246 - root_mean_squared_error: 0.1569 - val_loss: 0.0690 - val_root_mean_squared_error: 0.2626
# Epoch 20/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0242 - root_mean_squared_error: 0.1554 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2576

# %%
from tensorflow.keras.models import load_model
model1 = load_model('modelWIN_CNN/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model1.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()

m.update_state(l_actuals, l_preds)

rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 21/21 [==============================] - 0s 1ms/step
# The root mean squared error for the prediction: 0.13295916

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-02-01':'2005-02-28']
feb=temp.reset_index()

plt.style.use('seaborn')



winter= pd.concat([feb,df], axis=1)
winter.set_index("Time")
winter.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Feb 5th,2005')
winter.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Feb 5th,2005 to Feb 8th,2005')
# Out:
# C:\Users\prede\AppData\Local\Temp\ipykernel_1772\247656550.py:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <AxesSubplot: title={'center': 'Load Prediction for Feb 5th,2005 to Feb 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Spring season dataset training and prediction

# %%
X, y = dataframe_win(spr)
X.shape, y.shape
# Out:
# ((4409, 7, 6), (4409,))

# %%
X_train, y_train = X[:2208], y[:2208]
X_val, y_val = X[2208:3672], y[2208:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2208, 7, 6), (2208,), (1464, 7, 6), (1464,), (737, 7, 6), (737,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model2 = Sequential()
model2.add(InputLayer((7, 6)))
model2.add(Conv1D(64, kernel_size=2))
model2.add(Flatten()) 
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 6, 64)             832
#
#  flatten_1 (Flatten)         (None, 384)               0
#
#  dense_2 (Dense)             (None, 8)                 3080
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 3,921
# Trainable params: 3,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelSPR_CNN/', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 55/69 [======================>.......] - ETA: 0s - loss: 0.1767 - root_mean_squared_error: 0.4204
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 2s 18ms/step - loss: 0.1720 - root_mean_squared_error: 0.4148 - val_loss: 0.1770 - val_root_mean_squared_error: 0.4207
# Epoch 2/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1270 - root_mean_squared_error: 0.3563
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 19ms/step - loss: 0.1246 - root_mean_squared_error: 0.3529 - val_loss: 0.1398 - val_root_mean_squared_error: 0.3739
# Epoch 3/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1037 - root_mean_squared_error: 0.3219
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.1034 - root_mean_squared_error: 0.3215 - val_loss: 0.1196 - val_root_mean_squared_error: 0.3458
# Epoch 4/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0908 - root_mean_squared_error: 0.3013
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0898 - root_mean_squared_error: 0.2996 - val_loss: 0.1014 - val_root_mean_squared_error: 0.3184
# Epoch 5/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0785 - root_mean_squared_error: 0.2803
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0785 - root_mean_squared_error: 0.2801 - val_loss: 0.0896 - val_root_mean_squared_error: 0.2993
# Epoch 6/20
# 56/69 [=======================>......] - ETA: 0s - loss: 0.0720 - root_mean_squared_error: 0.2683
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0719 - root_mean_squared_error: 0.2682 - val_loss: 0.0805 - val_root_mean_squared_error: 0.2837
# Epoch 7/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0660 - root_mean_squared_error: 0.2570
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0662 - root_mean_squared_error: 0.2572 - val_loss: 0.0690 - val_root_mean_squared_error: 0.2626
# Epoch 8/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0629 - root_mean_squared_error: 0.2509
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0625 - root_mean_squared_error: 0.2501 - val_loss: 0.0659 - val_root_mean_squared_error: 0.2567
# Epoch 9/20
# 36/69 [==============>...............] - ETA: 0s - loss: 0.0618 - root_mean_squared_error: 0.2486
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0592 - root_mean_squared_error: 0.2432 - val_loss: 0.0610 - val_root_mean_squared_error: 0.2470
# Epoch 10/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0564 - root_mean_squared_error: 0.2376
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0570 - root_mean_squared_error: 0.2387 - val_loss: 0.0589 - val_root_mean_squared_error: 0.2428
# Epoch 11/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0544 - root_mean_squared_error: 0.2332
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0543 - root_mean_squared_error: 0.2329 - val_loss: 0.0552 - val_root_mean_squared_error: 0.2349
# Epoch 12/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0525 - root_mean_squared_error: 0.2292
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0518 - root_mean_squared_error: 0.2277 - val_loss: 0.0525 - val_root_mean_squared_error: 0.2292
# Epoch 13/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0501 - root_mean_squared_error: 0.2239
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0503 - root_mean_squared_error: 0.2243 - val_loss: 0.0480 - val_root_mean_squared_error: 0.2192
# Epoch 14/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.0452 - root_mean_squared_error: 0.2125
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0484 - root_mean_squared_error: 0.2200 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2171
# Epoch 15/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0468 - root_mean_squared_error: 0.2164
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0475 - root_mean_squared_error: 0.2180 - val_loss: 0.0445 - val_root_mean_squared_error: 0.2109
# Epoch 16/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0462 - root_mean_squared_error: 0.2148 - val_loss: 0.0452 - val_root_mean_squared_error: 0.2126
# Epoch 17/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0451 - root_mean_squared_error: 0.2123 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2111
# Epoch 18/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0440 - root_mean_squared_error: 0.2097
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0442 - root_mean_squared_error: 0.2102 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2036
# Epoch 19/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0439 - root_mean_squared_error: 0.2094
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# INFO:tensorflow:Assets written to: modelSPR_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0436 - root_mean_squared_error: 0.2089 - val_loss: 0.0392 - val_root_mean_squared_error: 0.1980
# Epoch 20/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0424 - root_mean_squared_error: 0.2059 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1994

# %%
from tensorflow.keras.models import load_model
model2 = load_model('modelSPR_CNN/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model2.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 24/24 [==============================] - 0s 1ms/step
# The root mean squared error for the prediction: 0.2213309

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-05-01':'2005-05-31']
may=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
spring= pd.concat([may,df], axis=1)
spring.set_index("Time")
spring.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,5,1,1,0,0),dt.datetime(2005,5,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for May 5th,2005')
spring.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,5,1,1,0,0),dt.datetime(2005,5,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for May 5th,2005 to May 8th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for May 5th,2005 to May 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Summer season dataset training and prediction

# %%
X, y = dataframe_win(sue)
X.shape, y.shape
# Out:
# ((4409, 7, 6), (4409,))

# %%
X_train, y_train = X[:2208], y[:2208]
X_val, y_val = X[2208:3672], y[2208:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2208, 7, 6), (2208,), (1464, 7, 6), (1464,), (737, 7, 6), (737,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model3 = Sequential()
model3.add(InputLayer((7, 6)))
model3.add(Conv1D(64, kernel_size=2))
model3.add(Flatten()) 
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 6, 64)             832
#
#  flatten_2 (Flatten)         (None, 384)               0
#
#  dense_4 (Dense)             (None, 8)                 3080
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 3,921
# Trainable params: 3,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelSUE_CNN/', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.4659 - root_mean_squared_error: 0.6826
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 2s 19ms/step - loss: 0.4623 - root_mean_squared_error: 0.6800 - val_loss: 0.4213 - val_root_mean_squared_error: 0.6491
# Epoch 2/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.1809 - root_mean_squared_error: 0.4254
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 19ms/step - loss: 0.1788 - root_mean_squared_error: 0.4228 - val_loss: 0.2355 - val_root_mean_squared_error: 0.4853
# Epoch 3/20
# 51/69 [=====================>........] - ETA: 0s - loss: 0.1289 - root_mean_squared_error: 0.3591
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 20ms/step - loss: 0.1286 - root_mean_squared_error: 0.3586 - val_loss: 0.1845 - val_root_mean_squared_error: 0.4296
# Epoch 4/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.1062 - root_mean_squared_error: 0.3259
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 22ms/step - loss: 0.1060 - root_mean_squared_error: 0.3255 - val_loss: 0.1605 - val_root_mean_squared_error: 0.4007
# Epoch 5/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0919 - root_mean_squared_error: 0.3032
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0913 - root_mean_squared_error: 0.3021 - val_loss: 0.1425 - val_root_mean_squared_error: 0.3774
# Epoch 6/20
# 48/69 [===================>..........] - ETA: 0s - loss: 0.0822 - root_mean_squared_error: 0.2868
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 22ms/step - loss: 0.0807 - root_mean_squared_error: 0.2841 - val_loss: 0.1197 - val_root_mean_squared_error: 0.3460
# Epoch 7/20
# 51/69 [=====================>........] - ETA: 0s - loss: 0.0749 - root_mean_squared_error: 0.2736
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0727 - root_mean_squared_error: 0.2696 - val_loss: 0.1101 - val_root_mean_squared_error: 0.3318
# Epoch 8/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0669 - root_mean_squared_error: 0.2586
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0669 - root_mean_squared_error: 0.2586 - val_loss: 0.1028 - val_root_mean_squared_error: 0.3207
# Epoch 9/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0630 - root_mean_squared_error: 0.2510
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0623 - root_mean_squared_error: 0.2495 - val_loss: 0.0966 - val_root_mean_squared_error: 0.3109
# Epoch 10/20
# 36/69 [==============>...............] - ETA: 0s - loss: 0.0593 - root_mean_squared_error: 0.2435
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 20ms/step - loss: 0.0586 - root_mean_squared_error: 0.2420 - val_loss: 0.0864 - val_root_mean_squared_error: 0.2939
# Epoch 11/20
# 57/69 [=======================>......] - ETA: 0s - loss: 0.0550 - root_mean_squared_error: 0.2345
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0557 - root_mean_squared_error: 0.2360 - val_loss: 0.0822 - val_root_mean_squared_error: 0.2867
# Epoch 12/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0524 - root_mean_squared_error: 0.2290 - val_loss: 0.0839 - val_root_mean_squared_error: 0.2897
# Epoch 13/20
# 56/69 [=======================>......] - ETA: 0s - loss: 0.0501 - root_mean_squared_error: 0.2238
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0503 - root_mean_squared_error: 0.2243 - val_loss: 0.0752 - val_root_mean_squared_error: 0.2742
# Epoch 14/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0477 - root_mean_squared_error: 0.2184 - val_loss: 0.0753 - val_root_mean_squared_error: 0.2744
# Epoch 15/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0458 - root_mean_squared_error: 0.2140
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0454 - root_mean_squared_error: 0.2131 - val_loss: 0.0678 - val_root_mean_squared_error: 0.2603
# Epoch 16/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0437 - root_mean_squared_error: 0.2091 - val_loss: 0.0695 - val_root_mean_squared_error: 0.2637
# Epoch 17/20
# 69/69 [==============================] - 0s 4ms/step - loss: 0.0420 - root_mean_squared_error: 0.2049 - val_loss: 0.0690 - val_root_mean_squared_error: 0.2627
# Epoch 18/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0404 - root_mean_squared_error: 0.2010
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0402 - root_mean_squared_error: 0.2005 - val_loss: 0.0635 - val_root_mean_squared_error: 0.2520
# Epoch 19/20
# 58/69 [========================>.....] - ETA: 0s - loss: 0.0389 - root_mean_squared_error: 0.1971
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# INFO:tensorflow:Assets written to: modelSUE_CNN\assets
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0388 - root_mean_squared_error: 0.1969 - val_loss: 0.0626 - val_root_mean_squared_error: 0.2503
# Epoch 20/20
# 69/69 [==============================] - 0s 3ms/step - loss: 0.0374 - root_mean_squared_error: 0.1935 - val_loss: 0.0643 - val_root_mean_squared_error: 0.2535

# %%
from tensorflow.keras.models import load_model
model3 = load_model('modelSUE_CNN/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model3.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 24/24 [==============================] - 0s 1ms/step
# The root mean squared error for the prediction: 0.19971053

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-08-01':'2005-08-31']
aug=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
summer= pd.concat([aug,df], axis=1)
summer.set_index("Time")
summer.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,8,20,1,0,0),dt.datetime(2005,8,20,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Aug 20th,2005')
summer.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,8,20,1,0,0),dt.datetime(2005,8,28,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Aug 20th,2005 to Aug 28th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for Aug 20th,2005 to Aug 28th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Fall season dataset training and prediction

# %%
X, y = dataframe_win(fal)
X.shape, y.shape
# Out:
# ((4336, 7, 6), (4336,))

# %%
X_train, y_train = X[:2184], y[:2184]
X_val, y_val = X[2184:3678], y[2184:3678]
X_test, y_test = X[3678:], y[3678:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2184, 7, 6), (2184,), (1494, 7, 6), (1494,), (658, 7, 6), (658,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model4 = Sequential()
model4.add(InputLayer((7, 6)))
model4.add(Conv1D(64, kernel_size=2))
model4.add(Flatten()) 
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 6, 64)             832
#
#  flatten_3 (Flatten)         (None, 384)               0
#
#  dense_6 (Dense)             (None, 8)                 3080
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 3,921
# Trainable params: 3,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelFAL_CNN/', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model4.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 59/69 [========================>.....] - ETA: 0s - loss: 1.1462 - root_mean_squared_error: 1.0706
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 2s 20ms/step - loss: 1.0794 - root_mean_squared_error: 1.0389 - val_loss: 0.2807 - val_root_mean_squared_error: 0.5298
# Epoch 2/20
# 55/69 [======================>.......] - ETA: 0s - loss: 0.4297 - root_mean_squared_error: 0.6555
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 17ms/step - loss: 0.4106 - root_mean_squared_error: 0.6408 - val_loss: 0.1999 - val_root_mean_squared_error: 0.4471
# Epoch 3/20
# 56/69 [=======================>......] - ETA: 0s - loss: 0.2736 - root_mean_squared_error: 0.5230
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 16ms/step - loss: 0.2644 - root_mean_squared_error: 0.5142 - val_loss: 0.1700 - val_root_mean_squared_error: 0.4124
# Epoch 4/20
# 55/69 [======================>.......] - ETA: 0s - loss: 0.2112 - root_mean_squared_error: 0.4596
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.2123 - root_mean_squared_error: 0.4608 - val_loss: 0.1440 - val_root_mean_squared_error: 0.3795
# Epoch 5/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.1843 - root_mean_squared_error: 0.4293
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 18ms/step - loss: 0.1820 - root_mean_squared_error: 0.4266 - val_loss: 0.1224 - val_root_mean_squared_error: 0.3498
# Epoch 6/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.1620 - root_mean_squared_error: 0.4025
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.1610 - root_mean_squared_error: 0.4013 - val_loss: 0.1096 - val_root_mean_squared_error: 0.3310
# Epoch 7/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.1462 - root_mean_squared_error: 0.3824
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.1448 - root_mean_squared_error: 0.3805 - val_loss: 0.1018 - val_root_mean_squared_error: 0.3191
# Epoch 8/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1323 - root_mean_squared_error: 0.3637
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.1313 - root_mean_squared_error: 0.3623 - val_loss: 0.0915 - val_root_mean_squared_error: 0.3026
# Epoch 9/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1205 - root_mean_squared_error: 0.3472
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.1197 - root_mean_squared_error: 0.3460 - val_loss: 0.0818 - val_root_mean_squared_error: 0.2860
# Epoch 10/20
# 57/69 [=======================>......] - ETA: 0s - loss: 0.1079 - root_mean_squared_error: 0.3284
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.1082 - root_mean_squared_error: 0.3290 - val_loss: 0.0725 - val_root_mean_squared_error: 0.2692
# Epoch 11/20
# 56/69 [=======================>......] - ETA: 0s - loss: 0.0952 - root_mean_squared_error: 0.3086
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0978 - root_mean_squared_error: 0.3128 - val_loss: 0.0644 - val_root_mean_squared_error: 0.2538
# Epoch 12/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.0908 - root_mean_squared_error: 0.3013
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0902 - root_mean_squared_error: 0.3003 - val_loss: 0.0607 - val_root_mean_squared_error: 0.2465
# Epoch 13/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0828 - root_mean_squared_error: 0.2877
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0840 - root_mean_squared_error: 0.2898 - val_loss: 0.0576 - val_root_mean_squared_error: 0.2401
# Epoch 14/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0796 - root_mean_squared_error: 0.2822
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0795 - root_mean_squared_error: 0.2819 - val_loss: 0.0541 - val_root_mean_squared_error: 0.2326
# Epoch 15/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0762 - root_mean_squared_error: 0.2761
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0756 - root_mean_squared_error: 0.2750 - val_loss: 0.0522 - val_root_mean_squared_error: 0.2285
# Epoch 16/20
# 50/69 [====================>.........] - ETA: 0s - loss: 0.0739 - root_mean_squared_error: 0.2719
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0726 - root_mean_squared_error: 0.2694 - val_loss: 0.0482 - val_root_mean_squared_error: 0.2194
# Epoch 17/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0708 - root_mean_squared_error: 0.2661
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 14ms/step - loss: 0.0701 - root_mean_squared_error: 0.2647 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2167
# Epoch 18/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0684 - root_mean_squared_error: 0.2616
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 18ms/step - loss: 0.0684 - root_mean_squared_error: 0.2616 - val_loss: 0.0454 - val_root_mean_squared_error: 0.2130
# Epoch 19/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0672 - root_mean_squared_error: 0.2592
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0661 - root_mean_squared_error: 0.2570 - val_loss: 0.0439 - val_root_mean_squared_error: 0.2096
# Epoch 20/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0653 - root_mean_squared_error: 0.2555
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# INFO:tensorflow:Assets written to: modelFAL_CNN\assets
# 69/69 [==============================] - 1s 15ms/step - loss: 0.0651 - root_mean_squared_error: 0.2551 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2064

# %%
from tensorflow.keras.models import load_model
model4 = load_model('modelFAL_CNN/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model4.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 21/21 [==============================] - 0s 1ms/step
# The root mean squared error for the prediction: 0.16443972

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-10-01':'2005-10-30']
nov=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
fall= pd.concat([nov,df], axis=1)
fall.set_index("Time")
fall.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,10,1,1,0,0),dt.datetime(2005,10,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Oct 1st,2005')
fall.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,10,1,1,0,0),dt.datetime(2005,10,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Oct 1st,2005 to Oct 8th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for Oct 1st,2005 to Oct 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>
