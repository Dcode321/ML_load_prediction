# %% [markdown]
# # Importing Libraries

# %% [markdown]
# Importing standard libraries necessary to organize and split data for neural network training. To use the LSTM Recurrent neural network, we use the tensorflow library keras. The model uses "Adam" as the optimizer and the activation function used is "Relu"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error as mse

# %%
ld = pd.read_csv("Load_data.csv")
ld.head()
# Out:
#    Load
# 0  1001
# 1   967
# 2   946
# 3   939
# 4   934

# %%
ld.plot()
ld.size
# Out:
# 17544

# %%
da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
r = np.array(da, dtype='datetime64[h]')
rr = pd.DataFrame(r, columns=['Time'])
rr.tail()
# Out:
# C:\Users\prede\AppData\Local\Temp\ipykernel_4548\1644015983.py:1: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
#                      Time
# 17539 2005-10-31 20:00:00
# 17540 2005-10-31 21:00:00
# 17541 2005-10-31 22:00:00
# 17542 2005-10-31 23:00:00
# 17543 2005-11-01 00:00:00

# %%
ldd = pd.concat([rr, ld], axis=1)
ldd.Time = pd.to_datetime(ldd.Time)
print(ldd.info())
ldd.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    17544 non-null  datetime64[ns]
#  1   Load    17544 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 274.2 KB
# None
#                  Time  Load
# 0 2003-11-01 01:00:00  1001
# 1 2003-11-01 02:00:00   967
# 2 2003-11-01 03:00:00   946
# 3 2003-11-01 04:00:00   939
# 4 2003-11-01 05:00:00   934

# %%
temp = pd.read_csv("temp.csv")
ldt = pd.concat([ldd, temp], axis=1)
ldt=ldt.set_index("Time")
ldt.head()
#The dataframe including the temperature data
# Out:
#                      Load  Temp (C)
# Time
# 2003-11-01 01:00:00  1001      16.8
# 2003-11-01 02:00:00   967      15.9
# 2003-11-01 03:00:00   946      15.9
# 2003-11-01 04:00:00   939      16.9
# 2003-11-01 05:00:00   934      16.3

# %%
# ldt.plot(y='Load', xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,8,23,0,0)])

# %%
#Generating the time in "Seconds" to generate a cos and sin map for periodicity relevance
ldt['Sec'] = ldt.index.map(pd.Timestamp.timestamp)
ldt
# Out:
#                      Load  Temp (C)           Sec
# Time
# 2003-11-01 01:00:00  1001      16.8  1.067648e+09
# 2003-11-01 02:00:00   967      15.9  1.067652e+09
# 2003-11-01 03:00:00   946      15.9  1.067656e+09
# 2003-11-01 04:00:00   939      16.9  1.067659e+09
# 2003-11-01 05:00:00   934      16.3  1.067663e+09
# ...                   ...       ...           ...
# 2005-10-31 20:00:00  1352      11.7  1.130789e+09
# 2005-10-31 21:00:00  1348      11.3  1.130792e+09
# 2005-10-31 22:00:00  1266      11.4  1.130796e+09
# 2005-10-31 23:00:00  1173      11.4  1.130800e+09
# 2005-11-01 00:00:00  1077      11.4  1.130803e+09
#
# [17544 rows x 3 columns]

# %%
day = 86400 
#86400 is the number of seconds in a day
year = 31556952 
#31556952 is the number of seconds in an year

ldt['DSin'] = np.sin(ldt['Sec'] * (2*np.pi /day))
ldt['DCos'] = np.cos(ldt['Sec'] * (2*np.pi /day))
ldt['YSin'] = np.sin(ldt['Sec'] * (2*np.pi /year))
ldt['YCos'] = np.cos(ldt['Sec'] * (2*np.pi /year))
ldt.head()
# Out:
#                      Load  Temp (C)           Sec      DSin      DCos  \
# Time
# 2003-11-01 01:00:00  1001      16.8  1.067648e+09  0.258819  0.965926
# 2003-11-01 02:00:00   967      15.9  1.067652e+09  0.500000  0.866025
# 2003-11-01 03:00:00   946      15.9  1.067656e+09  0.707107  0.707107
# 2003-11-01 04:00:00   939      16.9  1.067659e+09  0.866025  0.500000
# 2003-11-01 05:00:00   934      16.3  1.067663e+09  0.965926  0.258819
#
#                          YSin      YCos
# Time
# 2003-11-01 01:00:00 -0.868846  0.495082
# 2003-11-01 02:00:00 -0.868491  0.495704
# 2003-11-01 03:00:00 -0.868136  0.496327
# 2003-11-01 04:00:00 -0.867780  0.496949
# 2003-11-01 05:00:00 -0.867423  0.497571

# %%
ldt =ldt.drop('Sec', axis=1)
ldt.head()
#Dropping the "Seconds" column
# Out:
#                      Load  Temp (C)      DSin      DCos      YSin      YCos
# Time
# 2003-11-01 01:00:00  1001      16.8  0.258819  0.965926 -0.868846  0.495082
# 2003-11-01 02:00:00   967      15.9  0.500000  0.866025 -0.868491  0.495704
# 2003-11-01 03:00:00   946      15.9  0.707107  0.707107 -0.868136  0.496327
# 2003-11-01 04:00:00   939      16.9  0.866025  0.500000 -0.867780  0.496949
# 2003-11-01 05:00:00   934      16.3  0.965926  0.258819 -0.867423  0.497571

# %% [markdown]
# The Day sin and cos values with the Year sin and cos values shows the model that there exists a periodicity with a period of 24 hrs and as well as an whole year since the whole year is periodic in nature with offsets based on variable usage

# %% [markdown]
# ## Splitting the dataset based on seasons

# %%
win = pd.concat([ldt['2003-12-01':'2004-02-29'],ldt['2004-12-01':'2005-02-28']])
frames = [ldt['2003-11-01':'2003-11-30'],ldt['2004-09-01':'2004-11-30'],ldt['2005-09-01':'2005-10-30']]
fal = pd.concat(frames)
spr = pd.concat([ldt['2004-03-01':'2004-05-31'],ldt['2005-03-01':'2005-05-31']])
sue = pd.concat([ldt['2004-06-01':'2004-08-31'],ldt['2005-06-01':'2005-08-31']])


win.to_csv('win.csv',index=False)
fal.to_csv('fal.csv',index=False)
spr.to_csv('spr.csv',index=False)
sue.to_csv('sum.csv',index=False)

# %%
len(sue['2004-06-01':'2004-08-31'])
# Out:
# 2208

# %% [markdown]
# ## Sliding Window

# %%
#We generate the sliding window which is required for the LSTM model. The window size can be arbitrary and can depend on the dataset. Here, we use 5 hours of previous data to predict the next hour, Hence the size of the window will be 5. This can also be changed later for further tweaks to increase the accuracy of the model.
def dataframe_win(df, w_size=7):
    df_np = df.to_numpy()
    X=[]
    y=[]
    for i in range(len(df_np)-w_size):
        row =[r for r in df_np[i:i+w_size]]
        X.append(row)
        label = df_np[i+w_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %% [markdown]
# # Winter season dataset training and prediction

# %%
X, y = dataframe_win(win)
X.shape, y.shape
# Out:
# ((4337, 7, 6), (4337,))

# %%
X_train, y_train = X[:2184], y[:2184]
X_val, y_val = X[2184:3672], y[2184:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2184, 7, 6), (2184,), (1488, 7, 6), (1488,), (665, 7, 6), (665,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model1 = Sequential()
model1.add(InputLayer((7, 6)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 64)                18176
#
#  dense_10 (Dense)            (None, 8)                 520
#
#  dense_11 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelWIN_LSTM/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 67/69 [============================>.] - ETA: 0s - loss: 1.0790 - root_mean_squared_error: 1.0387
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 9s 93ms/step - loss: 1.0777 - root_mean_squared_error: 1.0381 - val_loss: 1.0524 - val_root_mean_squared_error: 1.0258
# Epoch 2/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.8327 - root_mean_squared_error: 0.9125
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.8163 - root_mean_squared_error: 0.9035 - val_loss: 0.7283 - val_root_mean_squared_error: 0.8534
# Epoch 3/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.5621 - root_mean_squared_error: 0.7497
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 78ms/step - loss: 0.5435 - root_mean_squared_error: 0.7372 - val_loss: 0.4729 - val_root_mean_squared_error: 0.6877
# Epoch 4/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.3778 - root_mean_squared_error: 0.6147
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.3711 - root_mean_squared_error: 0.6092 - val_loss: 0.3350 - val_root_mean_squared_error: 0.5788
# Epoch 5/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.2792 - root_mean_squared_error: 0.5284
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.2766 - root_mean_squared_error: 0.5259 - val_loss: 0.2655 - val_root_mean_squared_error: 0.5152
# Epoch 6/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.2251 - root_mean_squared_error: 0.4744
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.2215 - root_mean_squared_error: 0.4706 - val_loss: 0.2269 - val_root_mean_squared_error: 0.4763
# Epoch 7/20
# 69/69 [==============================] - ETA: 0s - loss: 0.1853 - root_mean_squared_error: 0.4305
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.1853 - root_mean_squared_error: 0.4305 - val_loss: 0.2057 - val_root_mean_squared_error: 0.4535
# Epoch 8/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1603 - root_mean_squared_error: 0.4004
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.1580 - root_mean_squared_error: 0.3975 - val_loss: 0.1898 - val_root_mean_squared_error: 0.4356
# Epoch 9/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.1382 - root_mean_squared_error: 0.3718
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.1362 - root_mean_squared_error: 0.3691 - val_loss: 0.1755 - val_root_mean_squared_error: 0.4189
# Epoch 10/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.1182 - root_mean_squared_error: 0.3438
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.1181 - root_mean_squared_error: 0.3436 - val_loss: 0.1641 - val_root_mean_squared_error: 0.4051
# Epoch 11/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.1064 - root_mean_squared_error: 0.3263
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 78ms/step - loss: 0.1030 - root_mean_squared_error: 0.3209 - val_loss: 0.1518 - val_root_mean_squared_error: 0.3897
# Epoch 12/20
# 57/69 [=======================>......] - ETA: 0s - loss: 0.0916 - root_mean_squared_error: 0.3027
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.0897 - root_mean_squared_error: 0.2995 - val_loss: 0.1434 - val_root_mean_squared_error: 0.3786
# Epoch 13/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0783 - root_mean_squared_error: 0.2799
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0783 - root_mean_squared_error: 0.2798 - val_loss: 0.1353 - val_root_mean_squared_error: 0.3678
# Epoch 14/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0688 - root_mean_squared_error: 0.2623
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 81ms/step - loss: 0.0690 - root_mean_squared_error: 0.2626 - val_loss: 0.1281 - val_root_mean_squared_error: 0.3580
# Epoch 15/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0615 - root_mean_squared_error: 0.2479
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.0615 - root_mean_squared_error: 0.2479 - val_loss: 0.1242 - val_root_mean_squared_error: 0.3525
# Epoch 16/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0548 - root_mean_squared_error: 0.2342
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0557 - root_mean_squared_error: 0.2360 - val_loss: 0.1184 - val_root_mean_squared_error: 0.3441
# Epoch 17/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0508 - root_mean_squared_error: 0.2254
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 79ms/step - loss: 0.0508 - root_mean_squared_error: 0.2255 - val_loss: 0.1167 - val_root_mean_squared_error: 0.3416
# Epoch 18/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0475 - root_mean_squared_error: 0.2179
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 6s 90ms/step - loss: 0.0472 - root_mean_squared_error: 0.2173 - val_loss: 0.1133 - val_root_mean_squared_error: 0.3365
# Epoch 19/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0442 - root_mean_squared_error: 0.2103
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 6s 91ms/step - loss: 0.0442 - root_mean_squared_error: 0.2103 - val_loss: 0.1099 - val_root_mean_squared_error: 0.3315
# Epoch 20/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0420 - root_mean_squared_error: 0.2049
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0420 - root_mean_squared_error: 0.2049 - val_loss: 0.1092 - val_root_mean_squared_error: 0.3304

# %%
from tensorflow.keras.models import load_model
model1 = load_model('modelWIN_LSTM/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model1.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms)
# Out:
# 21/21 [==============================] - 1s 4ms/step
# The root mean squared error for the prediction: 0.18558514

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-02-01':'2005-02-28']
feb=temp.reset_index()

plt.style.use('seaborn')



winter= pd.concat([feb,df], axis=1)
winter.set_index("Time")
winter.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Feb 5th,2005')
winter.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Feb 5th,2005 to Feb 8th,2005')
# Out:
# C:\Users\prede\AppData\Local\Temp\ipykernel_4548\247656550.py:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <AxesSubplot: title={'center': 'Load Prediction for Feb 5th,2005 to Feb 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Spring season dataset training and prediction

# %%
X, y = dataframe_win(spr)
X.shape, y.shape
# Out:
# ((4409, 7, 6), (4409,))

# %%
X_train, y_train = X[:2208], y[:2208]
X_val, y_val = X[2208:3672], y[2208:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2208, 7, 6), (2208,), (1464, 7, 6), (1464,), (737, 7, 6), (737,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model2 = Sequential()
model2.add(InputLayer((7, 6)))
model2.add(LSTM(64))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 64)                18176
#
#  dense_8 (Dense)             (None, 8)                 520
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelSPR_LSTM/', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.8273 - root_mean_squared_error: 0.9096
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 8s 89ms/step - loss: 0.8121 - root_mean_squared_error: 0.9012 - val_loss: 0.5543 - val_root_mean_squared_error: 0.7445
# Epoch 2/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.5916 - root_mean_squared_error: 0.7692
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.5869 - root_mean_squared_error: 0.7661 - val_loss: 0.4200 - val_root_mean_squared_error: 0.6481
# Epoch 3/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.4373 - root_mean_squared_error: 0.6613
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.4327 - root_mean_squared_error: 0.6578 - val_loss: 0.3320 - val_root_mean_squared_error: 0.5762
# Epoch 4/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.3176 - root_mean_squared_error: 0.5636
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.3143 - root_mean_squared_error: 0.5606 - val_loss: 0.2731 - val_root_mean_squared_error: 0.5226
# Epoch 5/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.2233 - root_mean_squared_error: 0.4725
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 6s 85ms/step - loss: 0.2249 - root_mean_squared_error: 0.4742 - val_loss: 0.2344 - val_root_mean_squared_error: 0.4841
# Epoch 6/20
# 57/69 [=======================>......] - ETA: 0s - loss: 0.1754 - root_mean_squared_error: 0.4188
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.1690 - root_mean_squared_error: 0.4111 - val_loss: 0.2086 - val_root_mean_squared_error: 0.4567
# Epoch 7/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1401 - root_mean_squared_error: 0.3743
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 6s 83ms/step - loss: 0.1387 - root_mean_squared_error: 0.3724 - val_loss: 0.1902 - val_root_mean_squared_error: 0.4361
# Epoch 8/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1220 - root_mean_squared_error: 0.3492
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.1220 - root_mean_squared_error: 0.3493 - val_loss: 0.1721 - val_root_mean_squared_error: 0.4149
# Epoch 9/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1126 - root_mean_squared_error: 0.3356
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.1110 - root_mean_squared_error: 0.3331 - val_loss: 0.1593 - val_root_mean_squared_error: 0.3991
# Epoch 10/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.1016 - root_mean_squared_error: 0.3188
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 79ms/step - loss: 0.1019 - root_mean_squared_error: 0.3192 - val_loss: 0.1469 - val_root_mean_squared_error: 0.3832
# Epoch 11/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.0947 - root_mean_squared_error: 0.3078
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 78ms/step - loss: 0.0944 - root_mean_squared_error: 0.3072 - val_loss: 0.1346 - val_root_mean_squared_error: 0.3668
# Epoch 12/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0887 - root_mean_squared_error: 0.2978
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.0874 - root_mean_squared_error: 0.2957 - val_loss: 0.1246 - val_root_mean_squared_error: 0.3530
# Epoch 13/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0799 - root_mean_squared_error: 0.2827
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 80ms/step - loss: 0.0808 - root_mean_squared_error: 0.2842 - val_loss: 0.1150 - val_root_mean_squared_error: 0.3391
# Epoch 14/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0758 - root_mean_squared_error: 0.2752
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 78ms/step - loss: 0.0753 - root_mean_squared_error: 0.2744 - val_loss: 0.1066 - val_root_mean_squared_error: 0.3266
# Epoch 15/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0707 - root_mean_squared_error: 0.2660
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.0706 - root_mean_squared_error: 0.2658 - val_loss: 0.0986 - val_root_mean_squared_error: 0.3140
# Epoch 16/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0665 - root_mean_squared_error: 0.2578
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 79ms/step - loss: 0.0667 - root_mean_squared_error: 0.2582 - val_loss: 0.0939 - val_root_mean_squared_error: 0.3064
# Epoch 17/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0647 - root_mean_squared_error: 0.2543
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0635 - root_mean_squared_error: 0.2519 - val_loss: 0.0870 - val_root_mean_squared_error: 0.2949
# Epoch 18/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0607 - root_mean_squared_error: 0.2463
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 78ms/step - loss: 0.0605 - root_mean_squared_error: 0.2460 - val_loss: 0.0808 - val_root_mean_squared_error: 0.2843
# Epoch 19/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0584 - root_mean_squared_error: 0.2417
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.0588 - root_mean_squared_error: 0.2425 - val_loss: 0.0792 - val_root_mean_squared_error: 0.2813
# Epoch 20/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0564 - root_mean_squared_error: 0.2375
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.0564 - root_mean_squared_error: 0.2375 - val_loss: 0.0754 - val_root_mean_squared_error: 0.2746

# %%
from tensorflow.keras.models import load_model
model2 = load_model('modelSPR_LSTM/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model2.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms)
# Out:
# 24/24 [==============================] - 1s 3ms/step
# The root mean squared error for the prediction: 0.2609055

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-05-01':'2005-05-31']
may=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
spring= pd.concat([may,df], axis=1)
spring.set_index("Time")
spring.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,5,1,1,0,0),dt.datetime(2005,5,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for May 5th,2005')
spring.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,5,1,1,0,0),dt.datetime(2005,5,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for May 5th,2005 to May 8th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for May 5th,2005 to May 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Summer season dataset training and prediction

# %%
X, y = dataframe_win(sue)
X.shape, y.shape
# Out:
# ((4409, 7, 6), (4409,))

# %%
X_train, y_train = X[:2208], y[:2208]
X_val, y_val = X[2208:3672], y[2208:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2208, 7, 6), (2208,), (1464, 7, 6), (1464,), (737, 7, 6), (737,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model3 = Sequential()
model3.add(InputLayer((7, 6)))
model3.add(LSTM(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 64)                18176
#
#  dense_4 (Dense)             (None, 8)                 520
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelSUE_LSTM/', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 60/69 [=========================>....] - ETA: 0s - loss: 1.0835 - root_mean_squared_error: 1.0409
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 7s 80ms/step - loss: 1.0842 - root_mean_squared_error: 1.0413 - val_loss: 1.9403 - val_root_mean_squared_error: 1.3930
# Epoch 2/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.8377 - root_mean_squared_error: 0.9153
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.8386 - root_mean_squared_error: 0.9157 - val_loss: 1.7153 - val_root_mean_squared_error: 1.3097
# Epoch 3/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.6908 - root_mean_squared_error: 0.8311
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 6s 83ms/step - loss: 0.6869 - root_mean_squared_error: 0.8288 - val_loss: 1.5583 - val_root_mean_squared_error: 1.2483
# Epoch 4/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.5653 - root_mean_squared_error: 0.7519
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.5638 - root_mean_squared_error: 0.7509 - val_loss: 1.3888 - val_root_mean_squared_error: 1.1785
# Epoch 5/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.4523 - root_mean_squared_error: 0.6725
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 80ms/step - loss: 0.4565 - root_mean_squared_error: 0.6757 - val_loss: 1.1896 - val_root_mean_squared_error: 1.0907
# Epoch 6/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.3618 - root_mean_squared_error: 0.6015
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.3613 - root_mean_squared_error: 0.6011 - val_loss: 0.9790 - val_root_mean_squared_error: 0.9895
# Epoch 7/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.2832 - root_mean_squared_error: 0.5321
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.2823 - root_mean_squared_error: 0.5313 - val_loss: 0.7715 - val_root_mean_squared_error: 0.8783
# Epoch 8/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.2281 - root_mean_squared_error: 0.4776
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.2275 - root_mean_squared_error: 0.4769 - val_loss: 0.6186 - val_root_mean_squared_error: 0.7865
# Epoch 9/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1928 - root_mean_squared_error: 0.4391
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.1924 - root_mean_squared_error: 0.4386 - val_loss: 0.5154 - val_root_mean_squared_error: 0.7179
# Epoch 10/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.1677 - root_mean_squared_error: 0.4095
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.1700 - root_mean_squared_error: 0.4124 - val_loss: 0.4460 - val_root_mean_squared_error: 0.6678
# Epoch 11/20
# 69/69 [==============================] - ETA: 0s - loss: 0.1537 - root_mean_squared_error: 0.3920
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.1537 - root_mean_squared_error: 0.3920 - val_loss: 0.3954 - val_root_mean_squared_error: 0.6288
# Epoch 12/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.1402 - root_mean_squared_error: 0.3744
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 80ms/step - loss: 0.1398 - root_mean_squared_error: 0.3739 - val_loss: 0.3576 - val_root_mean_squared_error: 0.5980
# Epoch 13/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1283 - root_mean_squared_error: 0.3582
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.1277 - root_mean_squared_error: 0.3574 - val_loss: 0.3206 - val_root_mean_squared_error: 0.5662
# Epoch 14/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1183 - root_mean_squared_error: 0.3439
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 6s 85ms/step - loss: 0.1166 - root_mean_squared_error: 0.3415 - val_loss: 0.2923 - val_root_mean_squared_error: 0.5407
# Epoch 15/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.1064 - root_mean_squared_error: 0.3261
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 79ms/step - loss: 0.1057 - root_mean_squared_error: 0.3252 - val_loss: 0.2662 - val_root_mean_squared_error: 0.5159
# Epoch 16/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0961 - root_mean_squared_error: 0.3099
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0959 - root_mean_squared_error: 0.3097 - val_loss: 0.2388 - val_root_mean_squared_error: 0.4887
# Epoch 17/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0872 - root_mean_squared_error: 0.2953
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.0872 - root_mean_squared_error: 0.2953 - val_loss: 0.2128 - val_root_mean_squared_error: 0.4613
# Epoch 18/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0796 - root_mean_squared_error: 0.2822
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 6s 86ms/step - loss: 0.0798 - root_mean_squared_error: 0.2825 - val_loss: 0.1911 - val_root_mean_squared_error: 0.4371
# Epoch 19/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.0733 - root_mean_squared_error: 0.2708
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0731 - root_mean_squared_error: 0.2703 - val_loss: 0.1718 - val_root_mean_squared_error: 0.4145
# Epoch 20/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0671 - root_mean_squared_error: 0.2590
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.0674 - root_mean_squared_error: 0.2597 - val_loss: 0.1657 - val_root_mean_squared_error: 0.4070

# %%
from tensorflow.keras.models import load_model
model3 = load_model('modelSUE_LSTM/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model3.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms)
# Out:
# 24/24 [==============================] - 1s 3ms/step
# The root mean squared error for the prediction: 0.2904636

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-08-01':'2005-08-31']
aug=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
summer= pd.concat([aug,df], axis=1)
summer.set_index("Time")
summer.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,8,20,1,0,0),dt.datetime(2005,8,20,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Aug 20th,2005')
summer.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,8,20,1,0,0),dt.datetime(2005,8,28,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Aug 20th,2005 to Aug 28th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for Aug 20th,2005 to Aug 28th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Fall season dataset training and prediction

# %%
X, y = dataframe_win(fal)
X.shape, y.shape
# Out:
# ((4336, 7, 6), (4336,))

# %%
X_train, y_train = X[:2184], y[:2184]
X_val, y_val = X[2184:3678], y[2184:3678]
X_test, y_test = X[3678:], y[3678:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2184, 7, 6), (2184,), (1494, 7, 6), (1494,), (658, 7, 6), (658,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model4 = Sequential()
model4.add(InputLayer((7, 6)))
model4.add(LSTM(64))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 64)                18176
#
#  dense_6 (Dense)             (None, 8)                 520
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelFAL_LSTM/', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model4.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.8314 - root_mean_squared_error: 0.9118
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 8s 89ms/step - loss: 0.8170 - root_mean_squared_error: 0.9039 - val_loss: 0.3987 - val_root_mean_squared_error: 0.6314
# Epoch 2/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.6031 - root_mean_squared_error: 0.7766
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 6s 81ms/step - loss: 0.5987 - root_mean_squared_error: 0.7738 - val_loss: 0.3104 - val_root_mean_squared_error: 0.5571
# Epoch 3/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.4507 - root_mean_squared_error: 0.6714
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.4527 - root_mean_squared_error: 0.6729 - val_loss: 0.2345 - val_root_mean_squared_error: 0.4842
# Epoch 4/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.3542 - root_mean_squared_error: 0.5952
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.3447 - root_mean_squared_error: 0.5872 - val_loss: 0.1885 - val_root_mean_squared_error: 0.4341
# Epoch 5/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.2783 - root_mean_squared_error: 0.5275
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.2781 - root_mean_squared_error: 0.5274 - val_loss: 0.1673 - val_root_mean_squared_error: 0.4090
# Epoch 6/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.2430 - root_mean_squared_error: 0.4930
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 79ms/step - loss: 0.2411 - root_mean_squared_error: 0.4910 - val_loss: 0.1479 - val_root_mean_squared_error: 0.3846
# Epoch 7/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.2149 - root_mean_squared_error: 0.4636
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.2141 - root_mean_squared_error: 0.4627 - val_loss: 0.1279 - val_root_mean_squared_error: 0.3576
# Epoch 8/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.1899 - root_mean_squared_error: 0.4358
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1899 - root_mean_squared_error: 0.4358 - val_loss: 0.1151 - val_root_mean_squared_error: 0.3393
# Epoch 9/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1724 - root_mean_squared_error: 0.4152
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.1712 - root_mean_squared_error: 0.4138 - val_loss: 0.1054 - val_root_mean_squared_error: 0.3247
# Epoch 10/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1563 - root_mean_squared_error: 0.3954
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1567 - root_mean_squared_error: 0.3959 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3114
# Epoch 11/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.3794
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1439 - root_mean_squared_error: 0.3793 - val_loss: 0.0842 - val_root_mean_squared_error: 0.2902
# Epoch 12/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1339 - root_mean_squared_error: 0.3659
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.1331 - root_mean_squared_error: 0.3649 - val_loss: 0.0768 - val_root_mean_squared_error: 0.2771
# Epoch 13/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1232 - root_mean_squared_error: 0.3510
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1232 - root_mean_squared_error: 0.3510 - val_loss: 0.0696 - val_root_mean_squared_error: 0.2639
# Epoch 14/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1154 - root_mean_squared_error: 0.3397
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1143 - root_mean_squared_error: 0.3381 - val_loss: 0.0656 - val_root_mean_squared_error: 0.2562
# Epoch 15/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1054 - root_mean_squared_error: 0.3247
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.1066 - root_mean_squared_error: 0.3266 - val_loss: 0.0605 - val_root_mean_squared_error: 0.2460
# Epoch 16/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1001 - root_mean_squared_error: 0.3165
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.0993 - root_mean_squared_error: 0.3152 - val_loss: 0.0539 - val_root_mean_squared_error: 0.2321
# Epoch 17/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0926 - root_mean_squared_error: 0.3043
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0932 - root_mean_squared_error: 0.3052 - val_loss: 0.0492 - val_root_mean_squared_error: 0.2218
# Epoch 18/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0874 - root_mean_squared_error: 0.2956
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 80ms/step - loss: 0.0878 - root_mean_squared_error: 0.2964 - val_loss: 0.0458 - val_root_mean_squared_error: 0.2139
# Epoch 19/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0829 - root_mean_squared_error: 0.2880
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.0830 - root_mean_squared_error: 0.2881 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2058
# Epoch 20/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0783 - root_mean_squared_error: 0.2798
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 6s 83ms/step - loss: 0.0795 - root_mean_squared_error: 0.2819 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020

# %%
from tensorflow.keras.models import load_model
model4 = load_model('modelFAL_LSTM/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model4.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 21/21 [==============================] - 1s 3ms/step
# The root mean squared error for the prediction: 0.19942106

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-10-01':'2005-10-30']
nov=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
fall= pd.concat([nov,df], axis=1)
fall.set_index("Time")
fall.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,10,1,1,0,0),dt.datetime(2005,10,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Oct 1st,2005')
fall.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,10,1,1,0,0),dt.datetime(2005,10,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Oct 1st,2005 to Oct 8th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for Oct 1st,2005 to Oct 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>
