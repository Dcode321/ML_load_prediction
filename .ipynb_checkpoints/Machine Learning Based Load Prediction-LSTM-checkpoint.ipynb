# %% [markdown]
# # Importing Libraries

# %% [markdown]
# Importing standard libraries necessary to organize and split data for neural network training. To use the LSTM Recurrent neural network, we use the tensorflow library keras. The model uses "Adam" as the optimizer and the activation function used is "Relu"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
ld = pd.read_csv("Load_data.csv")
ld.head()
# Out:
#    Load
# 0  1001
# 1   967
# 2   946
# 3   939
# 4   934

# %%
ld.plot()
ld.size
# Out:
# 17544

# %%
da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
r = np.array(da, dtype='datetime64[h]')
rr = pd.DataFrame(r, columns=['Time'])
rr.tail()
# Out:
# C:\Users\prede\AppData\Local\Temp\ipykernel_16724\1644015983.py:1: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
#                      Time
# 17539 2005-10-31 20:00:00
# 17540 2005-10-31 21:00:00
# 17541 2005-10-31 22:00:00
# 17542 2005-10-31 23:00:00
# 17543 2005-11-01 00:00:00

# %%
ldd = pd.concat([rr, ld], axis=1)
ldd.Time = pd.to_datetime(ldd.Time)
print(ldd.info())
ldd.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    17544 non-null  datetime64[ns]
#  1   Load    17544 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 274.2 KB
# None
#                  Time  Load
# 0 2003-11-01 01:00:00  1001
# 1 2003-11-01 02:00:00   967
# 2 2003-11-01 03:00:00   946
# 3 2003-11-01 04:00:00   939
# 4 2003-11-01 05:00:00   934

# %%
temp = pd.read_csv("temp.csv")
ldt = pd.concat([ldd, temp], axis=1)
ldt=ldt.set_index("Time")
ldt.head()
#The dataframe including the temperature data
# Out:
#                      Load  Temp (C)
# Time
# 2003-11-01 01:00:00  1001      16.8
# 2003-11-01 02:00:00   967      15.9
# 2003-11-01 03:00:00   946      15.9
# 2003-11-01 04:00:00   939      16.9
# 2003-11-01 05:00:00   934      16.3

# %%
# ldt.plot(y='Load', xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,8,23,0,0)])

# %%
#Generating the time in "Seconds" to generate a cos and sin map for periodicity relevance
ldt['Sec'] = ldt.index.map(pd.Timestamp.timestamp)
ldt
# Out:
#                      Load  Temp (C)           Sec
# Time
# 2003-11-01 01:00:00  1001      16.8  1.067648e+09
# 2003-11-01 02:00:00   967      15.9  1.067652e+09
# 2003-11-01 03:00:00   946      15.9  1.067656e+09
# 2003-11-01 04:00:00   939      16.9  1.067659e+09
# 2003-11-01 05:00:00   934      16.3  1.067663e+09
# ...                   ...       ...           ...
# 2005-10-31 20:00:00  1352      11.7  1.130789e+09
# 2005-10-31 21:00:00  1348      11.3  1.130792e+09
# 2005-10-31 22:00:00  1266      11.4  1.130796e+09
# 2005-10-31 23:00:00  1173      11.4  1.130800e+09
# 2005-11-01 00:00:00  1077      11.4  1.130803e+09
#
# [17544 rows x 3 columns]

# %%
day = 86400 
#86400 is the number of seconds in a day
year = 31556952 
#31556952 is the number of seconds in an year

ldt['DSin'] = np.sin(ldt['Sec'] * (2*np.pi /day))
ldt['DCos'] = np.cos(ldt['Sec'] * (2*np.pi /day))
ldt['YSin'] = np.sin(ldt['Sec'] * (2*np.pi /year))
ldt['YCos'] = np.cos(ldt['Sec'] * (2*np.pi /year))
ldt.head()
# Out:
#                      Load  Temp (C)           Sec      DSin      DCos  \
# Time
# 2003-11-01 01:00:00  1001      16.8  1.067648e+09  0.258819  0.965926
# 2003-11-01 02:00:00   967      15.9  1.067652e+09  0.500000  0.866025
# 2003-11-01 03:00:00   946      15.9  1.067656e+09  0.707107  0.707107
# 2003-11-01 04:00:00   939      16.9  1.067659e+09  0.866025  0.500000
# 2003-11-01 05:00:00   934      16.3  1.067663e+09  0.965926  0.258819
#
#                          YSin      YCos
# Time
# 2003-11-01 01:00:00 -0.868846  0.495082
# 2003-11-01 02:00:00 -0.868491  0.495704
# 2003-11-01 03:00:00 -0.868136  0.496327
# 2003-11-01 04:00:00 -0.867780  0.496949
# 2003-11-01 05:00:00 -0.867423  0.497571

# %%
ldt =ldt.drop('Sec', axis=1)
ldt.head()
#Dropping the "Seconds" column
# Out:
#                      Load  Temp (C)      DSin      DCos      YSin      YCos
# Time
# 2003-11-01 01:00:00  1001      16.8  0.258819  0.965926 -0.868846  0.495082
# 2003-11-01 02:00:00   967      15.9  0.500000  0.866025 -0.868491  0.495704
# 2003-11-01 03:00:00   946      15.9  0.707107  0.707107 -0.868136  0.496327
# 2003-11-01 04:00:00   939      16.9  0.866025  0.500000 -0.867780  0.496949
# 2003-11-01 05:00:00   934      16.3  0.965926  0.258819 -0.867423  0.497571

# %% [markdown]
# The Day sin and cos values with the Year sin and cos values shows the model that there exists a periodicity with a period of 24 hrs and as well as an whole year since the whole year is periodic in nature with offsets based on variable usage

# %% [markdown]
# ## Splitting the dataset based on seasons

# %%
win = pd.concat([ldt['2003-12-01':'2004-02-29'],ldt['2004-12-01':'2005-02-28']])
frames = [ldt['2003-11-01':'2003-11-30'],ldt['2004-09-01':'2004-11-30'],ldt['2005-09-01':'2005-10-30']]
fal = pd.concat(frames)
spr = pd.concat([ldt['2004-03-01':'2004-05-31'],ldt['2005-03-01':'2005-05-31']])
sue = pd.concat([ldt['2004-06-01':'2004-08-31'],ldt['2005-06-01':'2005-08-31']])


win.to_csv('win.csv',index=False)
fal.to_csv('fal.csv',index=False)
spr.to_csv('spr.csv',index=False)
sue.to_csv('sum.csv',index=False)

# %%
len(sue['2004-06-01':'2004-08-31'])
# Out:
# 2208

# %% [markdown]
# ## Sliding Window

# %%
#We generate the sliding window which is required for the LSTM model. The window size can be arbitrary and can depend on the dataset. Here, we use 5 hours of previous data to predict the next hour, Hence the size of the window will be 5. This can also be changed later for further tweaks to increase the accuracy of the model.
def dataframe_win(df, w_size=7):
    df_np = df.to_numpy()
    X=[]
    y=[]
    for i in range(len(df_np)-w_size):
        row =[r for r in df_np[i:i+w_size]]
        X.append(row)
        label = df_np[i+w_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %% [markdown]
# # Winter season dataset training and prediction

# %%
X, y = dataframe_win(win)
X.shape, y.shape
# Out:
# ((4337, 7, 6), (4337,))

# %%
X_train, y_train = X[:2184], y[:2184]
X_val, y_val = X[2184:3672], y[2184:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2184, 7, 6), (2184,), (1488, 7, 6), (1488,), (665, 7, 6), (665,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model = Sequential()
model.add(InputLayer((7, 6)))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 64)                18176
#
#  dense_10 (Dense)            (None, 8)                 520
#
#  dense_11 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelWIN_LSTM/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.7638 - root_mean_squared_error: 0.8739
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 6s 70ms/step - loss: 0.7635 - root_mean_squared_error: 0.8738 - val_loss: 0.6596 - val_root_mean_squared_error: 0.8122
# Epoch 2/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.5184 - root_mean_squared_error: 0.7200
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 65ms/step - loss: 0.5128 - root_mean_squared_error: 0.7161 - val_loss: 0.4149 - val_root_mean_squared_error: 0.6441
# Epoch 3/20
# 58/69 [========================>.....] - ETA: 0s - loss: 0.3491 - root_mean_squared_error: 0.5908
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.3397 - root_mean_squared_error: 0.5829 - val_loss: 0.2899 - val_root_mean_squared_error: 0.5385
# Epoch 4/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.2581 - root_mean_squared_error: 0.5080
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.2575 - root_mean_squared_error: 0.5075 - val_loss: 0.2431 - val_root_mean_squared_error: 0.4930
# Epoch 5/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.2149 - root_mean_squared_error: 0.4635
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.2148 - root_mean_squared_error: 0.4635 - val_loss: 0.2179 - val_root_mean_squared_error: 0.4668
# Epoch 6/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.1821 - root_mean_squared_error: 0.4267
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.1820 - root_mean_squared_error: 0.4266 - val_loss: 0.1942 - val_root_mean_squared_error: 0.4407
# Epoch 7/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.1544 - root_mean_squared_error: 0.3930
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.1539 - root_mean_squared_error: 0.3923 - val_loss: 0.1784 - val_root_mean_squared_error: 0.4224
# Epoch 8/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.1314 - root_mean_squared_error: 0.3625
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.1319 - root_mean_squared_error: 0.3632 - val_loss: 0.1623 - val_root_mean_squared_error: 0.4029
# Epoch 9/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.1162 - root_mean_squared_error: 0.3409
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.1148 - root_mean_squared_error: 0.3388 - val_loss: 0.1519 - val_root_mean_squared_error: 0.3897
# Epoch 10/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0997 - root_mean_squared_error: 0.3158
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0997 - root_mean_squared_error: 0.3158 - val_loss: 0.1393 - val_root_mean_squared_error: 0.3733
# Epoch 11/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0872 - root_mean_squared_error: 0.2952
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0872 - root_mean_squared_error: 0.2952 - val_loss: 0.1309 - val_root_mean_squared_error: 0.3617
# Epoch 12/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0771 - root_mean_squared_error: 0.2776
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.0758 - root_mean_squared_error: 0.2754 - val_loss: 0.1239 - val_root_mean_squared_error: 0.3520
# Epoch 13/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0669 - root_mean_squared_error: 0.2587
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0666 - root_mean_squared_error: 0.2580 - val_loss: 0.1178 - val_root_mean_squared_error: 0.3432
# Epoch 14/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0586 - root_mean_squared_error: 0.2421
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.0586 - root_mean_squared_error: 0.2420 - val_loss: 0.1145 - val_root_mean_squared_error: 0.3384
# Epoch 15/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0526 - root_mean_squared_error: 0.2294
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0526 - root_mean_squared_error: 0.2294 - val_loss: 0.1107 - val_root_mean_squared_error: 0.3327
# Epoch 16/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0485 - root_mean_squared_error: 0.2201
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 62ms/step - loss: 0.0483 - root_mean_squared_error: 0.2198 - val_loss: 0.1097 - val_root_mean_squared_error: 0.3312
# Epoch 17/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0444 - root_mean_squared_error: 0.2108
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 4s 65ms/step - loss: 0.0451 - root_mean_squared_error: 0.2123 - val_loss: 0.1061 - val_root_mean_squared_error: 0.3258
# Epoch 18/20
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0430 - root_mean_squared_error: 0.2073 - val_loss: 0.1072 - val_root_mean_squared_error: 0.3274
# Epoch 19/20
# 69/69 [==============================] - 1s 9ms/step - loss: 0.0410 - root_mean_squared_error: 0.2026 - val_loss: 0.1080 - val_root_mean_squared_error: 0.3287
# Epoch 20/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0399 - root_mean_squared_error: 0.1999
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# INFO:tensorflow:Assets written to: modelWIN_LSTM\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.0401 - root_mean_squared_error: 0.2002 - val_loss: 0.1046 - val_root_mean_squared_error: 0.3234

# %%
from tensorflow.keras.models import load_model
model = load_model('modelWIN_LSTM/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model.predict(X_test).flatten()
l_actuals = y_test

postprocess_output(l_preds)
postprocess_output(l_actuals)
# Out:
# 21/21 [==============================] - 1s 4ms/step

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-02-01':'2005-02-28']
feb=temp.reset_index()

plt.style.use('seaborn')



winter= pd.concat([feb,df], axis=1)
winter.set_index("Time")
winter.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Feb 5th,2005')
winter.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Feb 5th,2005 to Feb 8th,2005')
# Out:
# C:\Users\prede\AppData\Local\Temp\ipykernel_16724\247656550.py:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <AxesSubplot: title={'center': 'Load Prediction for Feb 5th,2005 to Feb 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Spring season dataset training and prediction

# %%
X, y = dataframe_win(spr)
X.shape, y.shape
# Out:
# ((4409, 7, 6), (4409,))

# %%
X_train, y_train = X[:2208], y[:2208]
X_val, y_val = X[2208:3672], y[2208:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2208, 7, 6), (2208,), (1464, 7, 6), (1464,), (737, 7, 6), (737,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model = Sequential()
model.add(InputLayer((7, 6)))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 64)                18176
#
#  dense_14 (Dense)            (None, 8)                 520
#
#  dense_15 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelSPR_LSTM/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.9859 - root_mean_squared_error: 0.9929
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 6s 69ms/step - loss: 0.9740 - root_mean_squared_error: 0.9869 - val_loss: 0.7621 - val_root_mean_squared_error: 0.8730
# Epoch 2/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.7813 - root_mean_squared_error: 0.8839
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.7787 - root_mean_squared_error: 0.8824 - val_loss: 0.6107 - val_root_mean_squared_error: 0.7815
# Epoch 3/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.5947 - root_mean_squared_error: 0.7711
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.5928 - root_mean_squared_error: 0.7700 - val_loss: 0.4669 - val_root_mean_squared_error: 0.6833
# Epoch 4/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.4247 - root_mean_squared_error: 0.6517
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 65ms/step - loss: 0.4161 - root_mean_squared_error: 0.6451 - val_loss: 0.3490 - val_root_mean_squared_error: 0.5908
# Epoch 5/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.2939 - root_mean_squared_error: 0.5421
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.2859 - root_mean_squared_error: 0.5347 - val_loss: 0.2829 - val_root_mean_squared_error: 0.5318
# Epoch 6/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.2156 - root_mean_squared_error: 0.4643
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 62ms/step - loss: 0.2130 - root_mean_squared_error: 0.4616 - val_loss: 0.2418 - val_root_mean_squared_error: 0.4918
# Epoch 7/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.1683 - root_mean_squared_error: 0.4103
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.1698 - root_mean_squared_error: 0.4121 - val_loss: 0.2097 - val_root_mean_squared_error: 0.4580
# Epoch 8/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1421 - root_mean_squared_error: 0.3770
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.1431 - root_mean_squared_error: 0.3782 - val_loss: 0.1863 - val_root_mean_squared_error: 0.4316
# Epoch 9/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.1290 - root_mean_squared_error: 0.3592
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.1264 - root_mean_squared_error: 0.3555 - val_loss: 0.1651 - val_root_mean_squared_error: 0.4063
# Epoch 10/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1142 - root_mean_squared_error: 0.3380
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.1146 - root_mean_squared_error: 0.3385 - val_loss: 0.1504 - val_root_mean_squared_error: 0.3878
# Epoch 11/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1058 - root_mean_squared_error: 0.3253
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.1044 - root_mean_squared_error: 0.3231 - val_loss: 0.1371 - val_root_mean_squared_error: 0.3703
# Epoch 12/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0978 - root_mean_squared_error: 0.3127
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 65ms/step - loss: 0.0962 - root_mean_squared_error: 0.3102 - val_loss: 0.1236 - val_root_mean_squared_error: 0.3515
# Epoch 13/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0893 - root_mean_squared_error: 0.2988
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.0898 - root_mean_squared_error: 0.2996 - val_loss: 0.1142 - val_root_mean_squared_error: 0.3379
# Epoch 14/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0850 - root_mean_squared_error: 0.2915
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0832 - root_mean_squared_error: 0.2884 - val_loss: 0.1066 - val_root_mean_squared_error: 0.3266
# Epoch 15/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0780 - root_mean_squared_error: 0.2792
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0781 - root_mean_squared_error: 0.2794 - val_loss: 0.1026 - val_root_mean_squared_error: 0.3204
# Epoch 16/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0743 - root_mean_squared_error: 0.2726
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0738 - root_mean_squared_error: 0.2717 - val_loss: 0.0929 - val_root_mean_squared_error: 0.3047
# Epoch 17/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0703 - root_mean_squared_error: 0.2651
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.0704 - root_mean_squared_error: 0.2653 - val_loss: 0.0902 - val_root_mean_squared_error: 0.3003
# Epoch 18/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0695 - root_mean_squared_error: 0.2637
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0676 - root_mean_squared_error: 0.2599 - val_loss: 0.0841 - val_root_mean_squared_error: 0.2901
# Epoch 19/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0635 - root_mean_squared_error: 0.2521
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0650 - root_mean_squared_error: 0.2549 - val_loss: 0.0807 - val_root_mean_squared_error: 0.2841
# Epoch 20/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0628 - root_mean_squared_error: 0.2507
# WARNING:absl:Found untraced functions such as lstm_cell_12_layer_call_fn, lstm_cell_12_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# INFO:tensorflow:Assets written to: modelSPR_LSTM\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.0626 - root_mean_squared_error: 0.2502 - val_loss: 0.0781 - val_root_mean_squared_error: 0.2794

# %%
from tensorflow.keras.models import load_model
model = load_model('modelSPR_LSTM/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model.predict(X_test).flatten()
l_actuals = y_test

postprocess_output(l_preds)
postprocess_output(l_actuals)
# Out:
# 24/24 [==============================] - 1s 3ms/step

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-05-01':'2005-05-31']
may=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
spring= pd.concat([may,df], axis=1)
spring.set_index("Time")
spring.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,5,1,1,0,0),dt.datetime(2005,5,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for May 5th,2005')
spring.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,5,1,1,0,0),dt.datetime(2005,5,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for May 5th,2005 to May 8th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for May 5th,2005 to May 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Summer season dataset training and prediction

# %%
X, y = dataframe_win(sue)
X.shape, y.shape
# Out:
# ((4409, 7, 6), (4409,))

# %%
X_train, y_train = X[:2208], y[:2208]
X_val, y_val = X[2208:3672], y[2208:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2208, 7, 6), (2208,), (1464, 7, 6), (1464,), (737, 7, 6), (737,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model = Sequential()
model.add(InputLayer((7, 6)))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 64)                18176
#
#  dense_18 (Dense)            (None, 8)                 520
#
#  dense_19 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelSUE_LSTM/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 69/69 [==============================] - ETA: 0s - loss: 0.8154 - root_mean_squared_error: 0.9030
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 6s 70ms/step - loss: 0.8154 - root_mean_squared_error: 0.9030 - val_loss: 1.5098 - val_root_mean_squared_error: 1.2287
# Epoch 2/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.5348 - root_mean_squared_error: 0.7313
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.5319 - root_mean_squared_error: 0.7293 - val_loss: 0.8337 - val_root_mean_squared_error: 0.9131
# Epoch 3/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.3121 - root_mean_squared_error: 0.5586
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.3070 - root_mean_squared_error: 0.5541 - val_loss: 0.5061 - val_root_mean_squared_error: 0.7114
# Epoch 4/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.2025 - root_mean_squared_error: 0.4500
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.2023 - root_mean_squared_error: 0.4498 - val_loss: 0.3768 - val_root_mean_squared_error: 0.6138
# Epoch 5/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1590 - root_mean_squared_error: 0.3987
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 62ms/step - loss: 0.1571 - root_mean_squared_error: 0.3964 - val_loss: 0.3036 - val_root_mean_squared_error: 0.5510
# Epoch 6/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.1326 - root_mean_squared_error: 0.3641
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 65ms/step - loss: 0.1310 - root_mean_squared_error: 0.3619 - val_loss: 0.2646 - val_root_mean_squared_error: 0.5144
# Epoch 7/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1108 - root_mean_squared_error: 0.3329
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.1124 - root_mean_squared_error: 0.3353 - val_loss: 0.2319 - val_root_mean_squared_error: 0.4815
# Epoch 8/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0986 - root_mean_squared_error: 0.3140
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.0983 - root_mean_squared_error: 0.3136 - val_loss: 0.2033 - val_root_mean_squared_error: 0.4509
# Epoch 9/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0871 - root_mean_squared_error: 0.2951
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.0867 - root_mean_squared_error: 0.2945 - val_loss: 0.1698 - val_root_mean_squared_error: 0.4120
# Epoch 10/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0767 - root_mean_squared_error: 0.2769
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0772 - root_mean_squared_error: 0.2778 - val_loss: 0.1502 - val_root_mean_squared_error: 0.3876
# Epoch 11/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0692 - root_mean_squared_error: 0.2631
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.0692 - root_mean_squared_error: 0.2631 - val_loss: 0.1216 - val_root_mean_squared_error: 0.3487
# Epoch 12/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0630 - root_mean_squared_error: 0.2510
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 65ms/step - loss: 0.0630 - root_mean_squared_error: 0.2509 - val_loss: 0.1168 - val_root_mean_squared_error: 0.3417
# Epoch 13/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0583 - root_mean_squared_error: 0.2415
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0578 - root_mean_squared_error: 0.2405 - val_loss: 0.1012 - val_root_mean_squared_error: 0.3181
# Epoch 14/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0540 - root_mean_squared_error: 0.2324
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.0538 - root_mean_squared_error: 0.2319 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074
# Epoch 15/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0505 - root_mean_squared_error: 0.2248
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 62ms/step - loss: 0.0507 - root_mean_squared_error: 0.2252 - val_loss: 0.0935 - val_root_mean_squared_error: 0.3058
# Epoch 16/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0482 - root_mean_squared_error: 0.2195
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.0483 - root_mean_squared_error: 0.2197 - val_loss: 0.0826 - val_root_mean_squared_error: 0.2874
# Epoch 17/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0464 - root_mean_squared_error: 0.2155
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# INFO:tensorflow:Assets written to: modelSUE_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0467 - root_mean_squared_error: 0.2162 - val_loss: 0.0807 - val_root_mean_squared_error: 0.2841
# Epoch 18/20
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0448 - root_mean_squared_error: 0.2116 - val_loss: 0.0836 - val_root_mean_squared_error: 0.2892
# Epoch 19/20
# 69/69 [==============================] - 1s 10ms/step - loss: 0.0436 - root_mean_squared_error: 0.2088 - val_loss: 0.0813 - val_root_mean_squared_error: 0.2851
# Epoch 20/20
# 69/69 [==============================] - 1s 11ms/step - loss: 0.0426 - root_mean_squared_error: 0.2065 - val_loss: 0.0823 - val_root_mean_squared_error: 0.2869

# %%
from tensorflow.keras.models import load_model
model = load_model('modelSUE_LSTM/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model.predict(X_test).flatten()
l_actuals = y_test

postprocess_output(l_preds)
postprocess_output(l_actuals)
# Out:
# 24/24 [==============================] - 1s 4ms/step

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-08-01':'2005-08-31']
aug=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
summer= pd.concat([aug,df], axis=1)
summer.set_index("Time")
summer.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,8,20,1,0,0),dt.datetime(2005,8,20,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Aug 20th,2005')
summer.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,8,20,1,0,0),dt.datetime(2005,8,28,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Aug 20th,2005 to Aug 28th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for Aug 20th,2005 to Aug 28th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Fall season dataset training and prediction

# %%
X, y = dataframe_win(fal)
X.shape, y.shape
# Out:
# ((4336, 7, 6), (4336,))

# %%
X_train, y_train = X[:2184], y[:2184]
X_val, y_val = X[2184:3678], y[2184:3678]
X_test, y_test = X[3678:], y[3678:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2184, 7, 6), (2184,), (1494, 7, 6), (1494,), (658, 7, 6), (658,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model = Sequential()
model.add(InputLayer((7, 6)))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 64)                18176
#
#  dense_20 (Dense)            (None, 8)                 520
#
#  dense_21 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 18,705
# Trainable params: 18,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelFAL_LSTM/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 69/69 [==============================] - ETA: 0s - loss: 0.7128 - root_mean_squared_error: 0.8443
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 7s 76ms/step - loss: 0.7128 - root_mean_squared_error: 0.8443 - val_loss: 0.3664 - val_root_mean_squared_error: 0.6053
# Epoch 2/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.4533 - root_mean_squared_error: 0.6733
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.4526 - root_mean_squared_error: 0.6727 - val_loss: 0.2493 - val_root_mean_squared_error: 0.4993
# Epoch 3/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.3090 - root_mean_squared_error: 0.5559
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.3086 - root_mean_squared_error: 0.5555 - val_loss: 0.1877 - val_root_mean_squared_error: 0.4332
# Epoch 4/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.2382 - root_mean_squared_error: 0.4880
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.2394 - root_mean_squared_error: 0.4893 - val_loss: 0.1544 - val_root_mean_squared_error: 0.3929
# Epoch 5/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.2074 - root_mean_squared_error: 0.4554
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.2046 - root_mean_squared_error: 0.4523 - val_loss: 0.1375 - val_root_mean_squared_error: 0.3709
# Epoch 6/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.1800 - root_mean_squared_error: 0.4243
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.1811 - root_mean_squared_error: 0.4255 - val_loss: 0.1210 - val_root_mean_squared_error: 0.3478
# Epoch 7/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1660 - root_mean_squared_error: 0.4075
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1626 - root_mean_squared_error: 0.4032 - val_loss: 0.1055 - val_root_mean_squared_error: 0.3249
# Epoch 8/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1476 - root_mean_squared_error: 0.3842
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1482 - root_mean_squared_error: 0.3849 - val_loss: 0.0979 - val_root_mean_squared_error: 0.3129
# Epoch 9/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1338 - root_mean_squared_error: 0.3658
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 78ms/step - loss: 0.1356 - root_mean_squared_error: 0.3683 - val_loss: 0.0885 - val_root_mean_squared_error: 0.2976
# Epoch 10/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1259 - root_mean_squared_error: 0.3548
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.1253 - root_mean_squared_error: 0.3539 - val_loss: 0.0808 - val_root_mean_squared_error: 0.2843
# Epoch 11/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1149 - root_mean_squared_error: 0.3390
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 65ms/step - loss: 0.1162 - root_mean_squared_error: 0.3409 - val_loss: 0.0751 - val_root_mean_squared_error: 0.2741
# Epoch 12/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1070 - root_mean_squared_error: 0.3272
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 63ms/step - loss: 0.1083 - root_mean_squared_error: 0.3291 - val_loss: 0.0685 - val_root_mean_squared_error: 0.2617
# Epoch 13/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1020 - root_mean_squared_error: 0.3194
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.1015 - root_mean_squared_error: 0.3186 - val_loss: 0.0627 - val_root_mean_squared_error: 0.2505
# Epoch 14/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0945 - root_mean_squared_error: 0.3074
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0948 - root_mean_squared_error: 0.3078 - val_loss: 0.0570 - val_root_mean_squared_error: 0.2386
# Epoch 15/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0897 - root_mean_squared_error: 0.2995
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0895 - root_mean_squared_error: 0.2991 - val_loss: 0.0524 - val_root_mean_squared_error: 0.2289
# Epoch 16/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0846 - root_mean_squared_error: 0.2908
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 4s 64ms/step - loss: 0.0843 - root_mean_squared_error: 0.2904 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2171
# Epoch 17/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0807 - root_mean_squared_error: 0.2840
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 66ms/step - loss: 0.0807 - root_mean_squared_error: 0.2841 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2111
# Epoch 18/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0768 - root_mean_squared_error: 0.2771
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0768 - root_mean_squared_error: 0.2771 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2028
# Epoch 19/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0727 - root_mean_squared_error: 0.2696
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 80ms/step - loss: 0.0735 - root_mean_squared_error: 0.2710 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2020
# Epoch 20/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0714 - root_mean_squared_error: 0.2671
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# INFO:tensorflow:Assets written to: modelFAL_LSTM\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.0713 - root_mean_squared_error: 0.2670 - val_loss: 0.0398 - val_root_mean_squared_error: 0.1996

# %%
from tensorflow.keras.models import load_model
model = load_model('modelFAL_LSTM/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model.predict(X_test).flatten()
l_actuals = y_test

postprocess_output(l_preds)
postprocess_output(l_actuals)
# Out:
# 21/21 [==============================] - 1s 4ms/step

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-10-01':'2005-10-30']
nov=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
fall= pd.concat([nov,df], axis=1)
fall.set_index("Time")
fall.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,10,1,1,0,0),dt.datetime(2005,10,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Oct 1st,2005')
fall.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,10,1,1,0,0),dt.datetime(2005,10,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Oct 1st,2005 to Oct 8th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for Oct 1st,2005 to Oct 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>
