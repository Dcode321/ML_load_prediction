# %% [markdown]
# # Importing Libraries

# %% [markdown]
# Importing standard libraries necessary to organize and split data for neural network training. To use the LSTM Recurrent neural network, we use the tensorflow library keras. The model uses "Adam" as the optimizer and the activation function used is "Relu"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.metrics import MAPE
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error as mse

# %%
ld = pd.read_csv("Load_data.csv")
ld.head()
# Out:
#    Load
# 0  1001
# 1   967
# 2   946
# 3   939
# 4   934

# %%
ld.plot()
ld.size
# Out:
# 17544

# %%
da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
r = np.array(da, dtype='datetime64[h]')
rr = pd.DataFrame(r, columns=['Time'])
rr.tail()
# Out:
# C:\Users\prede\AppData\Local\Temp\ipykernel_22824\1644015983.py:1: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
#                      Time
# 17539 2005-10-31 20:00:00
# 17540 2005-10-31 21:00:00
# 17541 2005-10-31 22:00:00
# 17542 2005-10-31 23:00:00
# 17543 2005-11-01 00:00:00

# %%
ldd = pd.concat([rr, ld], axis=1)
ldd.Time = pd.to_datetime(ldd.Time)
print(ldd.info())
ldd.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    17544 non-null  datetime64[ns]
#  1   Load    17544 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 274.2 KB
# None
#                  Time  Load
# 0 2003-11-01 01:00:00  1001
# 1 2003-11-01 02:00:00   967
# 2 2003-11-01 03:00:00   946
# 3 2003-11-01 04:00:00   939
# 4 2003-11-01 05:00:00   934

# %%
temp = pd.read_csv("temp.csv")
ldt = pd.concat([ldd, temp], axis=1)
ldt=ldt.set_index("Time")
ldt.head()
#The dataframe including the temperature data
# Out:
#                      Load  Temp (C)
# Time
# 2003-11-01 01:00:00  1001      16.8
# 2003-11-01 02:00:00   967      15.9
# 2003-11-01 03:00:00   946      15.9
# 2003-11-01 04:00:00   939      16.9
# 2003-11-01 05:00:00   934      16.3

# %%
# ldt.plot(y='Load', xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,8,23,0,0)])

# %%
#Generating the time in "Seconds" to generate a cos and sin map for periodicity relevance
ldt['Sec'] = ldt.index.map(pd.Timestamp.timestamp)
ldt
# Out:
#                      Load  Temp (C)           Sec
# Time
# 2003-11-01 01:00:00  1001      16.8  1.067648e+09
# 2003-11-01 02:00:00   967      15.9  1.067652e+09
# 2003-11-01 03:00:00   946      15.9  1.067656e+09
# 2003-11-01 04:00:00   939      16.9  1.067659e+09
# 2003-11-01 05:00:00   934      16.3  1.067663e+09
# ...                   ...       ...           ...
# 2005-10-31 20:00:00  1352      11.7  1.130789e+09
# 2005-10-31 21:00:00  1348      11.3  1.130792e+09
# 2005-10-31 22:00:00  1266      11.4  1.130796e+09
# 2005-10-31 23:00:00  1173      11.4  1.130800e+09
# 2005-11-01 00:00:00  1077      11.4  1.130803e+09
#
# [17544 rows x 3 columns]

# %%
day = 86400 
#86400 is the number of seconds in a day
year = 31556952 
#31556952 is the number of seconds in an year

ldt['DSin'] = np.sin(ldt['Sec'] * (2*np.pi /day))
ldt['DCos'] = np.cos(ldt['Sec'] * (2*np.pi /day))
ldt['YSin'] = np.sin(ldt['Sec'] * (2*np.pi /year))
ldt['YCos'] = np.cos(ldt['Sec'] * (2*np.pi /year))
ldt.head()
# Out:
#                      Load  Temp (C)           Sec      DSin      DCos  \
# Time
# 2003-11-01 01:00:00  1001      16.8  1.067648e+09  0.258819  0.965926
# 2003-11-01 02:00:00   967      15.9  1.067652e+09  0.500000  0.866025
# 2003-11-01 03:00:00   946      15.9  1.067656e+09  0.707107  0.707107
# 2003-11-01 04:00:00   939      16.9  1.067659e+09  0.866025  0.500000
# 2003-11-01 05:00:00   934      16.3  1.067663e+09  0.965926  0.258819
#
#                          YSin      YCos
# Time
# 2003-11-01 01:00:00 -0.868846  0.495082
# 2003-11-01 02:00:00 -0.868491  0.495704
# 2003-11-01 03:00:00 -0.868136  0.496327
# 2003-11-01 04:00:00 -0.867780  0.496949
# 2003-11-01 05:00:00 -0.867423  0.497571

# %%
ldt =ldt.drop('Sec', axis=1)
ldt.head()
#Dropping the "Seconds" column
# Out:
#                      Load  Temp (C)      DSin      DCos      YSin      YCos
# Time
# 2003-11-01 01:00:00  1001      16.8  0.258819  0.965926 -0.868846  0.495082
# 2003-11-01 02:00:00   967      15.9  0.500000  0.866025 -0.868491  0.495704
# 2003-11-01 03:00:00   946      15.9  0.707107  0.707107 -0.868136  0.496327
# 2003-11-01 04:00:00   939      16.9  0.866025  0.500000 -0.867780  0.496949
# 2003-11-01 05:00:00   934      16.3  0.965926  0.258819 -0.867423  0.497571

# %% [markdown]
# The Day sin and cos values with the Year sin and cos values shows the model that there exists a periodicity with a period of 24 hrs and as well as an whole year since the whole year is periodic in nature with offsets based on variable usage

# %% [markdown]
# ## Splitting the dataset based on seasons

# %%
win = pd.concat([ldt['2003-12-01':'2004-02-29'],ldt['2004-12-01':'2005-02-28']])
frames = [ldt['2003-11-01':'2003-11-30'],ldt['2004-09-01':'2004-11-30'],ldt['2005-09-01':'2005-10-30']]
fal = pd.concat(frames)
spr = pd.concat([ldt['2004-03-01':'2004-05-31'],ldt['2005-03-01':'2005-05-31']])
sue = pd.concat([ldt['2004-06-01':'2004-08-31'],ldt['2005-06-01':'2005-08-31']])


win.to_csv('win.csv',index=False)
fal.to_csv('fal.csv',index=False)
spr.to_csv('spr.csv',index=False)
sue.to_csv('sum.csv',index=False)

# %%
len(sue['2004-06-01':'2004-08-31'])
# Out:
# 2208

# %% [markdown]
# ## Sliding Window

# %%
#We generate the sliding window which is required for the LSTM model. The window size can be arbitrary and can depend on the dataset. Here, we use 5 hours of previous data to predict the next hour, Hence the size of the window will be 5. This can also be changed later for further tweaks to increase the accuracy of the model.
def dataframe_win(df, w_size=7):
    df_np = df.to_numpy()
    X=[]
    y=[]
    for i in range(len(df_np)-w_size):
        row =[r for r in df_np[i:i+w_size]]
        X.append(row)
        label = df_np[i+w_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %% [markdown]
# # Winter season dataset training and prediction

# %%
X, y = dataframe_win(win)
X.shape, y.shape
# Out:
# ((4337, 7, 6), (4337,))

# %%
X_train, y_train = X[:2184], y[:2184]
X_val, y_val = X[2184:3672], y[2184:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2184, 7, 6), (2184,), (1488, 7, 6), (1488,), (665, 7, 6), (665,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model1 = Sequential()
model1.add(InputLayer((7, 6)))
model1.add(GRU(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_9 (GRU)                 (None, 64)                13824
#
#  dense_18 (Dense)            (None, 8)                 520
#
#  dense_19 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 14,353
# Trainable params: 14,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelWIN_GRU/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 69/69 [==============================] - ETA: 0s - loss: 0.9824 - root_mean_squared_error: 0.9912
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 8s 94ms/step - loss: 0.9824 - root_mean_squared_error: 0.9912 - val_loss: 0.9637 - val_root_mean_squared_error: 0.9817
# Epoch 2/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.7568 - root_mean_squared_error: 0.8699
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.7447 - root_mean_squared_error: 0.8630 - val_loss: 0.7103 - val_root_mean_squared_error: 0.8428
# Epoch 3/20
# 69/69 [==============================] - ETA: 0s - loss: 0.5273 - root_mean_squared_error: 0.7261
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.5273 - root_mean_squared_error: 0.7261 - val_loss: 0.4806 - val_root_mean_squared_error: 0.6933
# Epoch 4/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.3730 - root_mean_squared_error: 0.6107
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.3725 - root_mean_squared_error: 0.6104 - val_loss: 0.3352 - val_root_mean_squared_error: 0.5790
# Epoch 5/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.2819 - root_mean_squared_error: 0.5309
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.2825 - root_mean_squared_error: 0.5315 - val_loss: 0.2568 - val_root_mean_squared_error: 0.5067
# Epoch 6/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.2293 - root_mean_squared_error: 0.4788
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.2271 - root_mean_squared_error: 0.4765 - val_loss: 0.2123 - val_root_mean_squared_error: 0.4608
# Epoch 7/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.1893 - root_mean_squared_error: 0.4350
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.1889 - root_mean_squared_error: 0.4347 - val_loss: 0.1844 - val_root_mean_squared_error: 0.4294
# Epoch 8/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.1604 - root_mean_squared_error: 0.4005
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.1604 - root_mean_squared_error: 0.4005 - val_loss: 0.1640 - val_root_mean_squared_error: 0.4049
# Epoch 9/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1402 - root_mean_squared_error: 0.3745
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1391 - root_mean_squared_error: 0.3729 - val_loss: 0.1477 - val_root_mean_squared_error: 0.3844
# Epoch 10/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.1207 - root_mean_squared_error: 0.3475
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.1213 - root_mean_squared_error: 0.3483 - val_loss: 0.1343 - val_root_mean_squared_error: 0.3664
# Epoch 11/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1084 - root_mean_squared_error: 0.3292
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.1062 - root_mean_squared_error: 0.3259 - val_loss: 0.1222 - val_root_mean_squared_error: 0.3495
# Epoch 12/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0934 - root_mean_squared_error: 0.3056
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.0932 - root_mean_squared_error: 0.3053 - val_loss: 0.1131 - val_root_mean_squared_error: 0.3363
# Epoch 13/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0816 - root_mean_squared_error: 0.2856
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.0819 - root_mean_squared_error: 0.2862 - val_loss: 0.1041 - val_root_mean_squared_error: 0.3227
# Epoch 14/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0721 - root_mean_squared_error: 0.2685
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.0722 - root_mean_squared_error: 0.2687 - val_loss: 0.0953 - val_root_mean_squared_error: 0.3086
# Epoch 15/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0649 - root_mean_squared_error: 0.2547
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 78ms/step - loss: 0.0644 - root_mean_squared_error: 0.2537 - val_loss: 0.0884 - val_root_mean_squared_error: 0.2973
# Epoch 16/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0573 - root_mean_squared_error: 0.2394
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0573 - root_mean_squared_error: 0.2395 - val_loss: 0.0829 - val_root_mean_squared_error: 0.2879
# Epoch 17/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0525 - root_mean_squared_error: 0.2292
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.0517 - root_mean_squared_error: 0.2274 - val_loss: 0.0769 - val_root_mean_squared_error: 0.2773
# Epoch 18/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0466 - root_mean_squared_error: 0.2159
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.0466 - root_mean_squared_error: 0.2158 - val_loss: 0.0731 - val_root_mean_squared_error: 0.2703
# Epoch 19/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0423 - root_mean_squared_error: 0.2058
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.0425 - root_mean_squared_error: 0.2063 - val_loss: 0.0697 - val_root_mean_squared_error: 0.2641
# Epoch 20/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0392 - root_mean_squared_error: 0.1981
# WARNING:absl:Found untraced functions such as gru_cell_18_layer_call_fn, gru_cell_18_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# INFO:tensorflow:Assets written to: modelWIN_GRU\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.0392 - root_mean_squared_error: 0.1980 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587

# %%
from tensorflow.keras.models import load_model
model1 = load_model('modelWIN_GRU/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model1.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()

m.update_state(l_actuals, l_preds)

rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 21/21 [==============================] - 1s 2ms/step
# The root mean squared error for the prediction: 0.16532393

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-02-01':'2005-02-28']
feb=temp.reset_index()

plt.style.use('seaborn')



winter= pd.concat([feb,df], axis=1)
winter.set_index("Time")
winter.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Feb 5th,2005')
winter.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,2,1,1,0,0),dt.datetime(2005,2,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Feb 5th,2005 to Feb 8th,2005')
# Out:
# C:\Users\prede\AppData\Local\Temp\ipykernel_22824\247656550.py:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <AxesSubplot: title={'center': 'Load Prediction for Feb 5th,2005 to Feb 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Spring season dataset training and prediction

# %%
X, y = dataframe_win(spr)
X.shape, y.shape
# Out:
# ((4409, 7, 6), (4409,))

# %%
X_train, y_train = X[:2208], y[:2208]
X_val, y_val = X[2208:3672], y[2208:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2208, 7, 6), (2208,), (1464, 7, 6), (1464,), (737, 7, 6), (737,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model2 = Sequential()
model2.add(InputLayer((7, 6)))
model2.add(GRU(64))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_10 (GRU)                (None, 64)                13824
#
#  dense_20 (Dense)            (None, 8)                 520
#
#  dense_21 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 14,353
# Trainable params: 14,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelSPR_GRU/', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.7974 - root_mean_squared_error: 0.8929
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 7s 75ms/step - loss: 0.7959 - root_mean_squared_error: 0.8921 - val_loss: 0.6304 - val_root_mean_squared_error: 0.7940
# Epoch 2/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.5773 - root_mean_squared_error: 0.7598
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.5699 - root_mean_squared_error: 0.7549 - val_loss: 0.4619 - val_root_mean_squared_error: 0.6797
# Epoch 3/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.4018 - root_mean_squared_error: 0.6339
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 66ms/step - loss: 0.3984 - root_mean_squared_error: 0.6312 - val_loss: 0.3311 - val_root_mean_squared_error: 0.5754
# Epoch 4/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.2910 - root_mean_squared_error: 0.5394
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.2825 - root_mean_squared_error: 0.5315 - val_loss: 0.2554 - val_root_mean_squared_error: 0.5054
# Epoch 5/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.2175 - root_mean_squared_error: 0.4663
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.2157 - root_mean_squared_error: 0.4644 - val_loss: 0.2181 - val_root_mean_squared_error: 0.4670
# Epoch 6/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.1768 - root_mean_squared_error: 0.4205
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1762 - root_mean_squared_error: 0.4197 - val_loss: 0.1924 - val_root_mean_squared_error: 0.4386
# Epoch 7/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.1503 - root_mean_squared_error: 0.3877
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.1494 - root_mean_squared_error: 0.3866 - val_loss: 0.1708 - val_root_mean_squared_error: 0.4133
# Epoch 8/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.1321 - root_mean_squared_error: 0.3634
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.1292 - root_mean_squared_error: 0.3595 - val_loss: 0.1556 - val_root_mean_squared_error: 0.3944
# Epoch 9/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.1123 - root_mean_squared_error: 0.3352
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1140 - root_mean_squared_error: 0.3377 - val_loss: 0.1437 - val_root_mean_squared_error: 0.3791
# Epoch 10/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1036 - root_mean_squared_error: 0.3219
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1028 - root_mean_squared_error: 0.3207 - val_loss: 0.1319 - val_root_mean_squared_error: 0.3632
# Epoch 11/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.0945 - root_mean_squared_error: 0.3073
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.0941 - root_mean_squared_error: 0.3067 - val_loss: 0.1232 - val_root_mean_squared_error: 0.3510
# Epoch 12/20
# 58/69 [========================>.....] - ETA: 0s - loss: 0.0895 - root_mean_squared_error: 0.2992
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.0873 - root_mean_squared_error: 0.2954 - val_loss: 0.1150 - val_root_mean_squared_error: 0.3391
# Epoch 13/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.0829 - root_mean_squared_error: 0.2879
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.0815 - root_mean_squared_error: 0.2856 - val_loss: 0.1084 - val_root_mean_squared_error: 0.3293
# Epoch 14/20
# 59/69 [========================>.....] - ETA: 0s - loss: 0.0758 - root_mean_squared_error: 0.2753
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 6s 82ms/step - loss: 0.0767 - root_mean_squared_error: 0.2769 - val_loss: 0.1027 - val_root_mean_squared_error: 0.3204
# Epoch 15/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0726 - root_mean_squared_error: 0.2694
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 6s 81ms/step - loss: 0.0725 - root_mean_squared_error: 0.2692 - val_loss: 0.0992 - val_root_mean_squared_error: 0.3149
# Epoch 16/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0685 - root_mean_squared_error: 0.2618
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.0685 - root_mean_squared_error: 0.2618 - val_loss: 0.0927 - val_root_mean_squared_error: 0.3044
# Epoch 17/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0649 - root_mean_squared_error: 0.2548
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.0651 - root_mean_squared_error: 0.2552 - val_loss: 0.0880 - val_root_mean_squared_error: 0.2966
# Epoch 18/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0624 - root_mean_squared_error: 0.2498
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.0619 - root_mean_squared_error: 0.2488 - val_loss: 0.0818 - val_root_mean_squared_error: 0.2860
# Epoch 19/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0595 - root_mean_squared_error: 0.2440
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.0588 - root_mean_squared_error: 0.2424 - val_loss: 0.0761 - val_root_mean_squared_error: 0.2759
# Epoch 20/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0574 - root_mean_squared_error: 0.2397
# WARNING:absl:Found untraced functions such as gru_cell_20_layer_call_fn, gru_cell_20_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# INFO:tensorflow:Assets written to: modelSPR_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.0563 - root_mean_squared_error: 0.2372 - val_loss: 0.0744 - val_root_mean_squared_error: 0.2727

# %%
from tensorflow.keras.models import load_model
model2 = load_model('modelSPR_GRU/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model2.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 24/24 [==============================] - 1s 3ms/step
# The root mean squared error for the prediction: 0.26826936

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-05-01':'2005-05-31']
may=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
spring= pd.concat([may,df], axis=1)
spring.set_index("Time")
spring.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,5,1,1,0,0),dt.datetime(2005,5,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for May 5th,2005')
spring.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,5,1,1,0,0),dt.datetime(2005,5,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for May 5th,2005 to May 8th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for May 5th,2005 to May 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Summer season dataset training and prediction

# %%
X, y = dataframe_win(sue)
X.shape, y.shape
# Out:
# ((4409, 7, 6), (4409,))

# %%
X_train, y_train = X[:2208], y[:2208]
X_val, y_val = X[2208:3672], y[2208:3672]
X_test, y_test = X[3672:], y[3672:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2208, 7, 6), (2208,), (1464, 7, 6), (1464,), (737, 7, 6), (737,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model3 = Sequential()
model3.add(InputLayer((7, 6)))
model3.add(GRU(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))

model3.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_11 (GRU)                (None, 64)                13824
#
#  dense_22 (Dense)            (None, 8)                 520
#
#  dense_23 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 14,353
# Trainable params: 14,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelSUE_GRU/', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.9544 - root_mean_squared_error: 0.9770
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 8s 80ms/step - loss: 0.9508 - root_mean_squared_error: 0.9751 - val_loss: 1.4844 - val_root_mean_squared_error: 1.2184
# Epoch 2/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.5309 - root_mean_squared_error: 0.7287
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.5275 - root_mean_squared_error: 0.7263 - val_loss: 1.0145 - val_root_mean_squared_error: 1.0072
# Epoch 3/20
# 69/69 [==============================] - ETA: 0s - loss: 0.2930 - root_mean_squared_error: 0.5413
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.2930 - root_mean_squared_error: 0.5413 - val_loss: 0.6607 - val_root_mean_squared_error: 0.8128
# Epoch 4/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.1874 - root_mean_squared_error: 0.4329
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.1864 - root_mean_squared_error: 0.4317 - val_loss: 0.4477 - val_root_mean_squared_error: 0.6691
# Epoch 5/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.1429 - root_mean_squared_error: 0.3780
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.1416 - root_mean_squared_error: 0.3763 - val_loss: 0.3528 - val_root_mean_squared_error: 0.5940
# Epoch 6/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.1204 - root_mean_squared_error: 0.3471
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 72ms/step - loss: 0.1191 - root_mean_squared_error: 0.3451 - val_loss: 0.2940 - val_root_mean_squared_error: 0.5422
# Epoch 7/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.1023 - root_mean_squared_error: 0.3199
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.1030 - root_mean_squared_error: 0.3210 - val_loss: 0.2599 - val_root_mean_squared_error: 0.5098
# Epoch 8/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0904 - root_mean_squared_error: 0.3007
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.0907 - root_mean_squared_error: 0.3012 - val_loss: 0.2223 - val_root_mean_squared_error: 0.4715
# Epoch 9/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0817 - root_mean_squared_error: 0.2859
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.0806 - root_mean_squared_error: 0.2840 - val_loss: 0.1956 - val_root_mean_squared_error: 0.4422
# Epoch 10/20
# 60/69 [=========================>....] - ETA: 0s - loss: 0.0744 - root_mean_squared_error: 0.2727
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 68ms/step - loss: 0.0725 - root_mean_squared_error: 0.2693 - val_loss: 0.1744 - val_root_mean_squared_error: 0.4176
# Epoch 11/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0662 - root_mean_squared_error: 0.2573
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.0653 - root_mean_squared_error: 0.2555 - val_loss: 0.1584 - val_root_mean_squared_error: 0.3980
# Epoch 12/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0598 - root_mean_squared_error: 0.2446
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441 - val_loss: 0.1405 - val_root_mean_squared_error: 0.3749
# Epoch 13/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0548 - root_mean_squared_error: 0.2340
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.0550 - root_mean_squared_error: 0.2346 - val_loss: 0.1274 - val_root_mean_squared_error: 0.3570
# Epoch 14/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0507 - root_mean_squared_error: 0.2252
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.0512 - root_mean_squared_error: 0.2263 - val_loss: 0.1138 - val_root_mean_squared_error: 0.3374
# Epoch 15/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0484 - root_mean_squared_error: 0.2199
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.0484 - root_mean_squared_error: 0.2201 - val_loss: 0.1052 - val_root_mean_squared_error: 0.3244
# Epoch 16/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0459 - root_mean_squared_error: 0.2142
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 4s 65ms/step - loss: 0.0459 - root_mean_squared_error: 0.2143 - val_loss: 0.0979 - val_root_mean_squared_error: 0.3129
# Epoch 17/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0436 - root_mean_squared_error: 0.2088
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.0440 - root_mean_squared_error: 0.2099 - val_loss: 0.0912 - val_root_mean_squared_error: 0.3021
# Epoch 18/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.0420 - root_mean_squared_error: 0.2049
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.0424 - root_mean_squared_error: 0.2059 - val_loss: 0.0852 - val_root_mean_squared_error: 0.2919
# Epoch 19/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.0416 - root_mean_squared_error: 0.2039
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.0413 - root_mean_squared_error: 0.2031 - val_loss: 0.0815 - val_root_mean_squared_error: 0.2854
# Epoch 20/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0401 - root_mean_squared_error: 0.2003
# WARNING:absl:Found untraced functions such as gru_cell_22_layer_call_fn, gru_cell_22_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# INFO:tensorflow:Assets written to: modelSUE_GRU\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.0401 - root_mean_squared_error: 0.2003 - val_loss: 0.0764 - val_root_mean_squared_error: 0.2764

# %%
from tensorflow.keras.models import load_model
model3 = load_model('modelSUE_GRU/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model3.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 24/24 [==============================] - 1s 3ms/step
# The root mean squared error for the prediction: 0.20505801

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-08-01':'2005-08-31']
aug=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
summer= pd.concat([aug,df], axis=1)
summer.set_index("Time")
summer.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,8,20,1,0,0),dt.datetime(2005,8,20,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Aug 20th,2005')
summer.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,8,20,1,0,0),dt.datetime(2005,8,28,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Aug 20th,2005 to Aug 28th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for Aug 20th,2005 to Aug 28th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>

# %% [markdown]
# # Fall season dataset training and prediction

# %%
X, y = dataframe_win(fal)
X.shape, y.shape
# Out:
# ((4336, 7, 6), (4336,))

# %%
X_train, y_train = X[:2184], y[:2184]
X_val, y_val = X[2184:3678], y[2184:3678]
X_test, y_test = X[3678:], y[3678:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((2184, 7, 6), (2184,), (1494, 7, 6), (1494,), (658, 7, 6), (658,))

# %%
load_train_mean = np.mean(X_train[:, :, 0])
load_train_std = np.std(X_train[:, :, 0])

temp_train_mean = np.mean(X_train[:, :, 1])
temp_train_std = np.std(X_train[:, :, 1])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - load_train_mean) / load_train_std
  X[:, :, 1] = (X[:, :, 1] - temp_train_mean) / temp_train_std

def preprocess_output(y):
  y[:] = (y[:] - load_train_mean) / load_train_std

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)
preprocess_output(y_train)
preprocess_output(y_val)
preprocess_output(y_test)

# %%
model4 = Sequential()
model4.add(InputLayer((7, 6)))
model4.add(GRU(64))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_12 (GRU)                (None, 64)                13824
#
#  dense_24 (Dense)            (None, 8)                 520
#
#  dense_25 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 14,353
# Trainable params: 14,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('modelFAL_GRU/', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model4.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])
# Out:
# Epoch 1/20
# 66/69 [===========================>..] - ETA: 0s - loss: 1.0081 - root_mean_squared_error: 1.0040
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 8s 82ms/step - loss: 1.0028 - root_mean_squared_error: 1.0014 - val_loss: 0.5234 - val_root_mean_squared_error: 0.7235
# Epoch 2/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.7084 - root_mean_squared_error: 0.8416
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.6915 - root_mean_squared_error: 0.8316 - val_loss: 0.3516 - val_root_mean_squared_error: 0.5929
# Epoch 3/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.4555 - root_mean_squared_error: 0.6749
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.4543 - root_mean_squared_error: 0.6740 - val_loss: 0.2269 - val_root_mean_squared_error: 0.4763
# Epoch 4/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.3026 - root_mean_squared_error: 0.5501
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.2972 - root_mean_squared_error: 0.5451 - val_loss: 0.1513 - val_root_mean_squared_error: 0.3890
# Epoch 5/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.2145 - root_mean_squared_error: 0.4632
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.2121 - root_mean_squared_error: 0.4605 - val_loss: 0.1170 - val_root_mean_squared_error: 0.3420
# Epoch 6/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.1719 - root_mean_squared_error: 0.4146
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.1721 - root_mean_squared_error: 0.4148 - val_loss: 0.1014 - val_root_mean_squared_error: 0.3184
# Epoch 7/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1531 - root_mean_squared_error: 0.3913
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 71ms/step - loss: 0.1513 - root_mean_squared_error: 0.3889 - val_loss: 0.0923 - val_root_mean_squared_error: 0.3038
# Epoch 8/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1350 - root_mean_squared_error: 0.3675
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.1376 - root_mean_squared_error: 0.3710 - val_loss: 0.0859 - val_root_mean_squared_error: 0.2930
# Epoch 9/20
# 66/69 [===========================>..] - ETA: 0s - loss: 0.1281 - root_mean_squared_error: 0.3580
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 75ms/step - loss: 0.1270 - root_mean_squared_error: 0.3564 - val_loss: 0.0794 - val_root_mean_squared_error: 0.2818
# Epoch 10/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.1183 - root_mean_squared_error: 0.3440
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 4s 66ms/step - loss: 0.1181 - root_mean_squared_error: 0.3437 - val_loss: 0.0743 - val_root_mean_squared_error: 0.2726
# Epoch 11/20
# 63/69 [==========================>...] - ETA: 0s - loss: 0.1115 - root_mean_squared_error: 0.3340
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 70ms/step - loss: 0.1101 - root_mean_squared_error: 0.3318 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2602
# Epoch 12/20
# 62/69 [=========================>....] - ETA: 0s - loss: 0.1035 - root_mean_squared_error: 0.3217
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 74ms/step - loss: 0.1030 - root_mean_squared_error: 0.3210 - val_loss: 0.0629 - val_root_mean_squared_error: 0.2508
# Epoch 13/20
# 68/69 [============================>.] - ETA: 0s - loss: 0.0968 - root_mean_squared_error: 0.3111
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.0968 - root_mean_squared_error: 0.3112 - val_loss: 0.0591 - val_root_mean_squared_error: 0.2432
# Epoch 14/20
# 61/69 [=========================>....] - ETA: 0s - loss: 0.0914 - root_mean_squared_error: 0.3024
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.0910 - root_mean_squared_error: 0.3016 - val_loss: 0.0555 - val_root_mean_squared_error: 0.2356
# Epoch 15/20
# 69/69 [==============================] - ETA: 0s - loss: 0.0860 - root_mean_squared_error: 0.2933
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 76ms/step - loss: 0.0860 - root_mean_squared_error: 0.2933 - val_loss: 0.0525 - val_root_mean_squared_error: 0.2292
# Epoch 16/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0822 - root_mean_squared_error: 0.2867
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 67ms/step - loss: 0.0818 - root_mean_squared_error: 0.2860 - val_loss: 0.0504 - val_root_mean_squared_error: 0.2245
# Epoch 17/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0778 - root_mean_squared_error: 0.2789
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 77ms/step - loss: 0.0776 - root_mean_squared_error: 0.2786 - val_loss: 0.0458 - val_root_mean_squared_error: 0.2141
# Epoch 18/20
# 67/69 [============================>.] - ETA: 0s - loss: 0.0736 - root_mean_squared_error: 0.2713
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.0740 - root_mean_squared_error: 0.2721 - val_loss: 0.0449 - val_root_mean_squared_error: 0.2119
# Epoch 19/20
# 65/69 [===========================>..] - ETA: 0s - loss: 0.0708 - root_mean_squared_error: 0.2661
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 69ms/step - loss: 0.0710 - root_mean_squared_error: 0.2664 - val_loss: 0.0421 - val_root_mean_squared_error: 0.2052
# Epoch 20/20
# 64/69 [==========================>...] - ETA: 0s - loss: 0.0677 - root_mean_squared_error: 0.2602
# WARNING:absl:Found untraced functions such as gru_cell_24_layer_call_fn, gru_cell_24_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# INFO:tensorflow:Assets written to: modelFAL_GRU\assets
# 69/69 [==============================] - 5s 73ms/step - loss: 0.0678 - root_mean_squared_error: 0.2604 - val_loss: 0.0394 - val_root_mean_squared_error: 0.1985

# %%
from tensorflow.keras.models import load_model
model4 = load_model('modelFAL_GRU/')

# %%
def postprocess_output(y):
  y[:] = (y[:] * load_train_std)  + load_train_mean

# %%
l_preds = model4.predict(X_test).flatten()
l_actuals = y_test

m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(l_actuals, l_preds)
rms= m.result().numpy()
print("The root mean squared error for the prediction:", rms )
# Out:
# 21/21 [==============================] - 1s 3ms/step
# The root mean squared error for the prediction: 0.15664276

# %%
postprocess_output(l_preds)
postprocess_output(l_actuals)

# %%
df = pd.DataFrame(data={'Load predictions': l_preds,
                          'Load Actuals':l_actuals,  })

#df.plot(xlim=[100,200])

temp=ldt['2005-10-01':'2005-10-30']
nov=temp.reset_index()

# pd.concat([df.set_index(cols).value for df in dfs],axis=1, keys=keys)
fall= pd.concat([nov,df], axis=1)
fall.set_index("Time")
fall.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,10,1,1,0,0),dt.datetime(2005,10,1,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Oct 1st,2005')
fall.plot(x='Time',y=['Load predictions', "Load Actuals"], xlim=[dt.datetime(2005,10,1,1,0,0),dt.datetime(2005,10,8,23,0,0)], ylabel='Load (Kw)', xlabel='Date and Time',title='Load Prediction for Oct 1st,2005 to Oct 8th,2005')
# Out:
# <AxesSubplot: title={'center': 'Load Prediction for Oct 1st,2005 to Oct 8th,2005'}, xlabel='Date and Time', ylabel='Load (Kw)'>
