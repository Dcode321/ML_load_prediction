# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
from tensorflow import keras
print('Tensorflow/Keras: %s' % keras.__version__)
from keras.models import sequential

# %%
ld = pd.read_csv("Load_data.csv")
ld.head()
# Out:
#    Load
# 0  1001
# 1   967
# 2   946
# 3   939
# 4   934

# %%
ld.plot()
# Out:
# <AxesSubplot:>

# %%
ld.size
# Out:
# 17544

# %%
da = pd.date_range(start='11/1/2003', end='11/1/2005', periods=17545, closed='right')
r = np.array(da, dtype='datetime64[h]')
rr = pd.DataFrame(r, columns=['Time'])
rr.head()
# Out:
#                  Time
# 0 2003-11-01 01:00:00
# 1 2003-11-01 02:00:00
# 2 2003-11-01 03:00:00
# 3 2003-11-01 04:00:00
# 4 2003-11-01 05:00:00

# %%
ldd = pd.concat([rr, ld], axis=1)
ldd.head()
# Out:
#                  Time  Load
# 0 2003-11-01 01:00:00  1001
# 1 2003-11-01 02:00:00   967
# 2 2003-11-01 03:00:00   946
# 3 2003-11-01 04:00:00   939
# 4 2003-11-01 05:00:00   934

# %%
ldd.Time = pd.to_datetime(ldd.Time)
ldd.head()
# Out:
#                  Time  Load
# 0 2003-11-01 01:00:00  1001
# 1 2003-11-01 02:00:00   967
# 2 2003-11-01 03:00:00   946
# 3 2003-11-01 04:00:00   939
# 4 2003-11-01 05:00:00   934

# %%
print(ldd.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    17544 non-null  datetime64[ns]
#  1   Load    17544 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 274.2 KB
# None

# %%
ldd.plot(x='Time', xlim=[dt.date(2004,8,1),dt.date(2004,12,15)])

plt.show()

# %%
ldd.to_csv('ldd.csv',index=False)

# %%
temp = pd.read_csv("temp.csv")
temp.head()
# Out:
#    Temp (C)
# 0      16.8
# 1      15.9
# 2      15.9
# 3      16.9
# 4      16.3

# %%
ldt = pd.concat([ldd, temp], axis=1)
ldt.head()
# Out:
#                  Time  Load  Temp (C)
# 0 2003-11-01 01:00:00  1001      16.8
# 1 2003-11-01 02:00:00   967      15.9
# 2 2003-11-01 03:00:00   946      15.9
# 3 2003-11-01 04:00:00   939      16.9
# 4 2003-11-01 05:00:00   934      16.3

# %%
ldt.plot(x='Time', xlim=[dt.date(2003,11,1),dt.date(2004,11,30)])

plt.show()

# %%
tempd = pd.concat([rr, temp], axis=1)
tempd.head()
# Out:
#                  Time  Temp (C)
# 0 2003-11-01 01:00:00      16.8
# 1 2003-11-01 02:00:00      15.9
# 2 2003-11-01 03:00:00      15.9
# 3 2003-11-01 04:00:00      16.9
# 4 2003-11-01 05:00:00      16.3

# %%
tempd.plot(x="Time", xlim=[dt.date(2004,11,1),dt.date(2004,12,1)])
# Out:
# <AxesSubplot:xlabel='Time'>
